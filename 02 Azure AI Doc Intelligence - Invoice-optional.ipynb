# %% [markdown]
# # 02. Azure AI Document Intelligence - Invoice Model

# %% [markdown]
# > https://learn.microsoft.com/en-us/azure/ai-services/document-intelligence/overview?view=doc-intel-4.0.0

# %% [markdown]
# ## A. Create an AI Document Intelligence resource and set up environment to run notebook
#
# **_Prerequsite_:** <br>
#
# **AI Document Intelligence resource**: <br>
# To create a AI Document Intelligence resource in your Azure subscription:
# Please follow the steps as specified https://learn.microsoft.com/en-us/azure/ai-services/document-intelligence/create-document-intelligence-resource?view=doc-intel-4.0.0
#
#
# Get your newly created Document Intelligence service in the Azure portal and on the **Keys and Endpoint** page, copy the **Key1** and **Endpoint** values and paste them in the code cell below, replacing **YOUR_FORM_KEY** and **YOUR_FORM_ENDPOINT**.

# %% [markdown]
# **Environment: **
#
# 1. **AML workspace**: Please ensure you have Python 3.10 version or above ie select **Python 3.10 - SDK v2** as kernel in AML Notebook. <br>
# 2. **VS Code**: Please select Python **Python 3.10** above or try to set up virtual envi by following steps https://code.visualstudio.com/docs/python/environments
#
# Please skip this step if you are already done it

# %% [markdown]
# ## B. Install AI Doc Intelligence library

# %%
# install azure-ai-formrecognizer python library and restart the kernal after installation
# ignore this step is you have already installed azure-ai-formrecognizer python library
# %pip install azure-ai-formrecognizer --upgrade --user
# Out:
# Requirement already satisfied: azure-ai-formrecognizer in /home/azureuser/.local/lib/python3.10/site-packages (3.3.3)
# Requirement already satisfied: azure-core>=1.23.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-ai-formrecognizer) (1.27.1)
# Requirement already satisfied: msrest>=0.6.21 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-ai-formrecognizer) (0.7.1)
# Requirement already satisfied: azure-common>=1.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-ai-formrecognizer) (1.1.28)
# Requirement already satisfied: typing-extensions>=4.0.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-ai-formrecognizer) (4.6.3)
# Requirement already satisfied: requests>=2.18.4 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-core>=1.23.0->azure-ai-formrecognizer) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-core>=1.23.0->azure-ai-formrecognizer) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (2023.5.7)
# Requirement already satisfied: isodate>=0.6.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.18.4->azure-core>=1.23.0->azure-ai-formrecognizer) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.18.4->azure-core>=1.23.0->azure-ai-formrecognizer) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.18.4->azure-core>=1.23.0->azure-ai-formrecognizer) (1.26.16)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-formrecognizer) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## C. Setting up AI Doc Intelligence endpoint and key

# %%
# Import the os module for interacting with the operating system
import os
# Import for handling resource not found errors
from azure.core.exceptions import ResourceNotFoundError
# Import for authenticating with the Azure service
from azure.core.credentials import AzureKeyCredential
# Import for analysing forms
from azure.ai.formrecognizer import DocumentAnalysisClient, AnalyzeResult

from dotenv import load_dotenv

load_dotenv("credentials.env")
api_key=os.getenv("FORM_RECOGNIZER_KEY")
endpoint = os.getenv("FORM_RECOGNIZER_ENDPOINT") 

# Create a DocumentAnalysisClient instance
# This client is used to interact with the Azure Form Recognizer service
# It is initialized with your endpoint and key
form_recognizer_client = DocumentAnalysisClient(endpoint, AzureKeyCredential(api_key))

# %% [markdown]
# ## D. Extract the Invoice Document

# %%
# Define the URL of the sample invoice document to analyze
# You can change the URL pointing to your sample invoice docs but ensure you provide appropriate access
invoiceUrl = "XXXX"

# Start the analysis of the invoice document using the prebuilt invoice model
# The result is a poller object that can be used to check the status of the operation
poller = form_recognizer_client.begin_analyze_document_from_url("prebuilt-invoice",invoiceUrl)

# Print the poller object. This is useful for debugging purposes to ensure the analysis has started correctly.
print(poller)

# Get the result of the analysis
result = poller.result()

# Print the documents in the result. This will display the analyzed information from the invoice document.
print(result.documents)
# Out:
# <azure.core.polling._poller.LROPoller object at 0x7f7ca069a830>
# [AnalyzedDocument(doc_type=invoice, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=0.0, y=0.0), Point(x=8.5, y=0.0), Point(x=8.5, y=11.0), Point(x=0.0, y=11.0)])], spans=[DocumentSpan(offset=0, length=226)], fields={'CustomerAddress': DocumentField(value_type=address, value=AddressValue(house_number=1020, po_box=None, road=Enterprise Way
# Sunnayvale, CA 87659, city=None, state=None, postal_code=None, country_region=None, street_address=1020 Enterprise Way
# Sunnayvale, CA 87659, unit=None, city_district=None, state_district=None, suburb=None, house=None, level=None), content=1020 Enterprise Way
# Sunnayvale, CA 87659, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=5.186, y=1.6901), Point(x=6.6615, y=1.6901), Point(x=6.6615, y=2.0482), Point(x=5.186, y=2.0482)])], spans=[DocumentSpan(offset=60, length=19), DocumentSpan(offset=97, length=20)], confidence=0.992), 'CustomerAddressRecipient': DocumentField(value_type=string, value='Microsoft', content=Microsoft, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=5.1812, y=1.4848), Point(x=5.8211, y=1.4848), Point(x=5.8211, y=1.6424), Point(x=5.1812, y=1.6471)])], spans=[DocumentSpan(offset=30, length=9)], confidence=0.985), 'CustomerName': DocumentField(value_type=string, value='Microsoft', content=Microsoft, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=5.1812, y=1.4848), Point(x=5.8211, y=1.4848), Point(x=5.8211, y=1.6424), Point(x=5.1812, y=1.6471)])], spans=[DocumentSpan(offset=30, length=9)], confidence=0.985), 'DueDate': DocumentField(value_type=date, value=datetime.date(2017, 6, 24), content=6/24/2017, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=3.3331, y=3.385), Point(x=3.9444, y=3.3802), Point(x=3.9492, y=3.5425), Point(x=3.3284, y=3.5425)])], spans=[DocumentSpan(offset=203, length=9)], confidence=0.989), 'InvoiceDate': DocumentField(value_type=date, value=datetime.date(2017, 6, 18), content=6/18/2017, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1.9292, y=3.3898), Point(x=2.5596, y=3.3898), Point(x=2.5596, y=3.533), Point(x=1.934, y=3.533)])], spans=[DocumentSpan(offset=193, length=9)], confidence=0.988), 'InvoiceId': DocumentField(value_type=string, value='34278587', content=34278587, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=0.5301, y=3.3945), Point(x=1.1508, y=3.3993), Point(x=1.1461, y=3.533), Point(x=0.5301, y=3.5282)])], spans=[DocumentSpan(offset=184, length=8)], confidence=0.987), 'InvoiceTotal': DocumentField(value_type=currency, value=CurrencyValue(amount=56651.49, symbol=$, code=USD), content=$56,651.49, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=5.3626, y=3.3898), Point(x=6.0789, y=3.3898), Point(x=6.0837, y=3.5473), Point(x=5.3579, y=3.5569)])], spans=[DocumentSpan(offset=213, length=10)], confidence=0.866), 'Items': DocumentField(value_type=list, value=[DocumentField(value_type=dictionary, value={'Amount': DocumentField(value_type=currency, value=CurrencyValue(amount=56651.49, symbol=$, code=USD), content=$56,651.49, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=5.3626, y=3.3898), Point(x=6.0789, y=3.3898), Point(x=6.0837, y=3.5473), Point(x=5.3579, y=3.5569)])], spans=[DocumentSpan(offset=213, length=10)], confidence=0.72), 'Date': DocumentField(value_type=date, value=datetime.date(2017, 6, 24), content=6/18/2017
# 6/24/2017, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=1.9292, y=3.3802), Point(x=3.9492, y=3.3802), Point(x=3.9492, y=3.5425), Point(x=1.9292, y=3.5425)])], spans=[DocumentSpan(offset=193, length=19)], confidence=0.703), 'ProductCode': DocumentField(value_type=string, value='34278587', content=34278587, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=0.5301, y=3.3945), Point(x=1.1508, y=3.3993), Point(x=1.1461, y=3.533), Point(x=0.5301, y=3.5282)])], spans=[DocumentSpan(offset=184, length=8)], confidence=0.826)}, content=34278587
# 6/18/2017
# 6/24/2017
# $56,651.49
# PT, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=0.5301, y=3.3802), Point(x=6.3941, y=3.3802), Point(x=6.3941, y=3.5569), Point(x=0.5301, y=3.5569)])], spans=[DocumentSpan(offset=184, length=42)], confidence=0.631)], content=None, bounding_regions=[], spans=[], confidence=None), 'VendorAddress': DocumentField(value_type=address, value=AddressValue(house_number=1, po_box=None, road=Redmond way, city=Redmond, state=WA, postal_code=99243, country_region=None, street_address=1 Redmond way Suite
# 6000, unit=Suite
# 6000, city_district=None, state_district=None, suburb=None, house=None, level=None), content=1 Redmond way Suite
# 6000 Redmond, WA
# 99243, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=0.7831, y=1.6806), Point(x=2.1441, y=1.6806), Point(x=2.1441, y=2.2057), Point(x=0.7831, y=2.2057)])], spans=[DocumentSpan(offset=40, length=19), DocumentSpan(offset=80, length=16), DocumentSpan(offset=118, length=5)], confidence=0.995), 'VendorName': DocumentField(value_type=string, value='Contoso', content=Contoso, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=0.5348, y=1.1458), Point(x=1.4374, y=1.1506), Point(x=1.4326, y=1.375), Point(x=0.5301, y=1.3798)])], spans=[DocumentSpan(offset=0, length=7)], confidence=0.342)}, confidence=1.0)]

# %% [markdown]
# ## E. Extracted Layout Document insights/ response as a JSON format

# %%
# Import necessary libraries
# json for handling JSON data
# datetime and time for generating timestamps
# AzureJSONEncoder for serializing Python objects to JSON
# urlparse for parsing URLs
import json
import datetime
import time
from azure.core.serialization import AzureJSONEncoder
from urllib.parse import urlparse


# Generate a unique filename based on the current timestamp and the basename of the URL
filename = datetime.datetime.fromtimestamp(time.time()).strftime('%Y%m%d%H%M%S')+"_"+os.path.splitext(os.path.basename(urlparse(invoiceUrl).path))[0]

# Convert the result of the analysis (which is a model) to a dictionary
analyze_result_dict = result.to_dict()

# Open a new file with the generated filename and write the dictionary to it as JSON
# Use the AzureJSONEncoder to handle any types that aren't serializable by default
with open(str(filename), 'w') as f:
        json.dump(analyze_result_dict, f, cls=AzureJSONEncoder,indent=4)

# Convert the dictionary back to the original model
model = AnalyzeResult.from_dict(analyze_result_dict)

# Print some information about the model
print("--------------JSON Response from Model Starts---------------------")
# use the model as normal
print("Model ID: '{}'".format(model.model_id))
print("Number of pages analyzed {}".format(len(model.pages)))
print("API version used: {}".format(model.api_version))

# Print the dictionary (which is the JSON response from the model)
print(json.dumps(analyze_result_dict,cls=AzureJSONEncoder,indent=4))
print("--------------JSON Response from Model Ends---------------------")
# Out:
# --------------JSON Response from Model Starts---------------------
# Model ID: 'prebuilt-invoice'
# Number of pages analyzed 1
# API version used: 2023-07-31
# {
#     "api_version": "2023-07-31",
#     "model_id": "prebuilt-invoice",
#     "content": "Contoso\nAddress:\nInvoice For: Microsoft\n1 Redmond way Suite\n1020 Enterprise Way\n6000 Redmond, WA\nSunnayvale, CA 87659\n99243\nInvoice Number\nInvoice Date\nInvoice Due Date\nCharges\nVAT ID\n34278587\n6/18/2017\n6/24/2017\n$56,651.49\nPT",
#     "languages": [],
#     "pages": [
#         {
#             "page_number": 1,
#             "angle": null,
#             "width": 8.5,
#             "height": 11.0,
#             "unit": "inch",
#             "lines": [
#                 {
#                     "content": "Contoso",
#                     "polygon": [
#                         {
#                             "x": 0.5301,
#                             "y": 1.1458
#                         },
#                         {
#                             "x": 1.4517,
#                             "y": 1.1458
#                         },
#                         {
#                             "x": 1.4517,
#                             "y": 1.3702
#                         },
#                         {
#                             "x": 0.5301,
#                             "y": 1.375
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 0,
#                             "length": 7
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Address:",
#                     "polygon": [
#                         {
#                             "x": 0.7831,
#                             "y": 1.4991
#                         },
#                         {
#                             "x": 1.3992,
#                             "y": 1.4991
#                         },
#                         {
#                             "x": 1.3992,
#                             "y": 1.628
#                         },
#                         {
#                             "x": 0.7831,
#                             "y": 1.628
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 8,
#                             "length": 8
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Invoice For: Microsoft",
#                     "polygon": [
#                         {
#                             "x": 4.3789,
#                             "y": 1.4848
#                         },
#                         {
#                             "x": 5.8258,
#                             "y": 1.48
#                         },
#                         {
#                             "x": 5.8258,
#                             "y": 1.6424
#                         },
#                         {
#                             "x": 4.3789,
#                             "y": 1.6424
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 17,
#                             "length": 22
#                         }
#                     ]
#                 },
#                 {
#                     "content": "1 Redmond way Suite",
#                     "polygon": [
#                         {
#                             "x": 0.8022,
#                             "y": 1.6806
#                         },
#                         {
#                             "x": 2.1489,
#                             "y": 1.6806
#                         },
#                         {
#                             "x": 2.1489,
#                             "y": 1.8381
#                         },
#                         {
#                             "x": 0.8022,
#                             "y": 1.8381
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 40,
#                             "length": 19
#                         }
#                     ]
#                 },
#                 {
#                     "content": "1020 Enterprise Way",
#                     "polygon": [
#                         {
#                             "x": 5.186,
#                             "y": 1.6853
#                         },
#                         {
#                             "x": 6.5469,
#                             "y": 1.6901
#                         },
#                         {
#                             "x": 6.5469,
#                             "y": 1.862
#                         },
#                         {
#                             "x": 5.186,
#                             "y": 1.8572
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 60,
#                             "length": 19
#                         }
#                     ]
#                 },
#                 {
#                     "content": "6000 Redmond, WA",
#                     "polygon": [
#                         {
#                             "x": 0.7831,
#                             "y": 1.8668
#                         },
#                         {
#                             "x": 2.0438,
#                             "y": 1.8668
#                         },
#                         {
#                             "x": 2.039,
#                             "y": 2.0243
#                         },
#                         {
#                             "x": 0.7831,
#                             "y": 2.0195
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 80,
#                             "length": 16
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Sunnayvale, CA 87659",
#                     "polygon": [
#                         {
#                             "x": 5.1764,
#                             "y": 1.8763
#                         },
#                         {
#                             "x": 6.6711,
#                             "y": 1.8715
#                         },
#                         {
#                             "x": 6.6711,
#                             "y": 2.0386
#                         },
#                         {
#                             "x": 5.1764,
#                             "y": 2.0434
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 97,
#                             "length": 20
#                         }
#                     ]
#                 },
#                 {
#                     "content": "99243",
#                     "polygon": [
#                         {
#                             "x": 0.7784,
#                             "y": 2.0673
#                         },
#                         {
#                             "x": 1.1747,
#                             "y": 2.0673
#                         },
#                         {
#                             "x": 1.1747,
#                             "y": 2.201
#                         },
#                         {
#                             "x": 0.7784,
#                             "y": 2.201
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 118,
#                             "length": 5
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Invoice Number",
#                     "polygon": [
#                         {
#                             "x": 0.5157,
#                             "y": 2.855
#                         },
#                         {
#                             "x": 1.5806,
#                             "y": 2.855
#                         },
#                         {
#                             "x": 1.5806,
#                             "y": 2.9887
#                         },
#                         {
#                             "x": 0.5157,
#                             "y": 2.9935
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 124,
#                             "length": 14
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Invoice Date",
#                     "polygon": [
#                         {
#                             "x": 1.9292,
#                             "y": 2.855
#                         },
#                         {
#                             "x": 2.7601,
#                             "y": 2.855
#                         },
#                         {
#                             "x": 2.7601,
#                             "y": 2.9935
#                         },
#                         {
#                             "x": 1.9292,
#                             "y": 2.9887
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 139,
#                             "length": 12
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Invoice Due Date",
#                     "polygon": [
#                         {
#                             "x": 3.3236,
#                             "y": 2.8503
#                         },
#                         {
#                             "x": 4.4649,
#                             "y": 2.8503
#                         },
#                         {
#                             "x": 4.4649,
#                             "y": 3.003
#                         },
#                         {
#                             "x": 3.3236,
#                             "y": 2.9983
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 152,
#                             "length": 16
#                         }
#                     ]
#                 },
#                 {
#                     "content": "Charges",
#                     "polygon": [
#                         {
#                             "x": 4.7275,
#                             "y": 2.855
#                         },
#                         {
#                             "x": 5.3053,
#                             "y": 2.855
#                         },
#                         {
#                             "x": 5.3006,
#                             "y": 3.0126
#                         },
#                         {
#                             "x": 4.7275,
#                             "y": 3.0078
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 169,
#                             "length": 7
#                         }
#                     ]
#                 },
#                 {
#                     "content": "VAT ID",
#                     "polygon": [
#                         {
#                             "x": 6.1219,
#                             "y": 2.8503
#                         },
#                         {
#                             "x": 6.5994,
#                             "y": 2.8503
#                         },
#                         {
#                             "x": 6.5994,
#                             "y": 2.9887
#                         },
#                         {
#                             "x": 6.1267,
#                             "y": 2.9935
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 177,
#                             "length": 6
#                         }
#                     ]
#                 },
#                 {
#                     "content": "34278587",
#                     "polygon": [
#                         {
#                             "x": 0.5205,
#                             "y": 3.3945
#                         },
#                         {
#                             "x": 1.1508,
#                             "y": 3.3945
#                         },
#                         {
#                             "x": 1.1461,
#                             "y": 3.5282
#                         },
#                         {
#                             "x": 0.5205,
#                             "y": 3.5282
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 184,
#                             "length": 8
#                         }
#                     ]
#                 },
#                 {
#                     "content": "6/18/2017",
#                     "polygon": [
#                         {
#                             "x": 1.9197,
#                             "y": 3.3898
#                         },
#                         {
#                             "x": 2.5596,
#                             "y": 3.3898
#                         },
#                         {
#                             "x": 2.5596,
#                             "y": 3.5282
#                         },
#                         {
#                             "x": 1.9197,
#                             "y": 3.5282
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 193,
#                             "length": 9
#                         }
#                     ]
#                 },
#                 {
#                     "content": "6/24/2017",
#                     "polygon": [
#                         {
#                             "x": 3.3236,
#                             "y": 3.3802
#                         },
#                         {
#                             "x": 3.9492,
#                             "y": 3.3802
#                         },
#                         {
#                             "x": 3.9492,
#                             "y": 3.5378
#                         },
#                         {
#                             "x": 3.3236,
#                             "y": 3.5425
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 203,
#                             "length": 9
#                         }
#                     ]
#                 },
#                 {
#                     "content": "$56,651.49",
#                     "polygon": [
#                         {
#                             "x": 5.3579,
#                             "y": 3.385
#                         },
#                         {
#                             "x": 6.0789,
#                             "y": 3.385
#                         },
#                         {
#                             "x": 6.0789,
#                             "y": 3.5473
#                         },
#                         {
#                             "x": 5.3579,
#                             "y": 3.5521
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 213,
#                             "length": 10
#                         }
#                     ]
#                 },
#                 {
#                     "content": "PT",
#                     "polygon": [
#                         {
#                             "x": 6.1983,
#                             "y": 3.3945
#                         },
#                         {
#                             "x": 6.4037,
#                             "y": 3.3898
#                         },
#                         {
#                             "x": 6.4037,
#                             "y": 3.533
#                         },
#                         {
#                             "x": 6.2031,
#                             "y": 3.5234
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 224,
#                             "length": 2
#                         }
#                     ]
#                 }
#             ],
#             "words": [
#                 {
#                     "content": "Contoso",
#                     "polygon": [
#                         {
#                             "x": 0.5348,
#                             "y": 1.1458
#                         },
#                         {
#                             "x": 1.4374,
#                             "y": 1.1506
#                         },
#                         {
#                             "x": 1.4326,
#                             "y": 1.375
#                         },
#                         {
#                             "x": 0.5301,
#                             "y": 1.3798
#                         }
#                     ],
#                     "span": {
#                         "offset": 0,
#                         "length": 7
#                     },
#                     "confidence": 0.995
#                 },
#                 {
#                     "content": "Address:",
#                     "polygon": [
#                         {
#                             "x": 0.7975,
#                             "y": 1.5087
#                         },
#                         {
#                             "x": 1.3992,
#                             "y": 1.5039
#                         },
#                         {
#                             "x": 1.3992,
#                             "y": 1.628
#                         },
#                         {
#                             "x": 0.8022,
#                             "y": 1.628
#                         }
#                     ],
#                     "span": {
#                         "offset": 8,
#                         "length": 8
#                     },
#                     "confidence": 0.995
#                 },
#                 {
#                     "content": "Invoice",
#                     "polygon": [
#                         {
#                             "x": 4.3837,
#                             "y": 1.4944
#                         },
#                         {
#                             "x": 4.8183,
#                             "y": 1.4896
#                         },
#                         {
#                             "x": 4.8183,
#                             "y": 1.6424
#                         },
#                         {
#                             "x": 4.3885,
#                             "y": 1.6328
#                         }
#                     ],
#                     "span": {
#                         "offset": 17,
#                         "length": 7
#                     },
#                     "confidence": 0.982
#                 },
#                 {
#                     "content": "For:",
#                     "polygon": [
#                         {
#                             "x": 4.8565,
#                             "y": 1.4896
#                         },
#                         {
#                             "x": 5.143,
#                             "y": 1.4896
#                         },
#                         {
#                             "x": 5.143,
#                             "y": 1.6471
#                         },
#                         {
#                             "x": 4.8565,
#                             "y": 1.6424
#                         }
#                     ],
#                     "span": {
#                         "offset": 25,
#                         "length": 4
#                     },
#                     "confidence": 0.993
#                 },
#                 {
#                     "content": "Microsoft",
#                     "polygon": [
#                         {
#                             "x": 5.1812,
#                             "y": 1.4848
#                         },
#                         {
#                             "x": 5.8211,
#                             "y": 1.4848
#                         },
#                         {
#                             "x": 5.8211,
#                             "y": 1.6424
#                         },
#                         {
#                             "x": 5.1812,
#                             "y": 1.6471
#                         }
#                     ],
#                     "span": {
#                         "offset": 30,
#                         "length": 9
#                     },
#                     "confidence": 0.994
#                 },
#                 {
#                     "content": "1",
#                     "polygon": [
#                         {
#                             "x": 0.807,
#                             "y": 1.6901
#                         },
#                         {
#                             "x": 0.8643,
#                             "y": 1.6901
#                         },
#                         {
#                             "x": 0.8691,
#                             "y": 1.8333
#                         },
#                         {
#                             "x": 0.8118,
#                             "y": 1.8333
#                         }
#                     ],
#                     "span": {
#                         "offset": 40,
#                         "length": 1
#                     },
#                     "confidence": 0.995
#                 },
#                 {
#                     "content": "Redmond",
#                     "polygon": [
#                         {
#                             "x": 0.893,
#                             "y": 1.6853
#                         },
#                         {
#                             "x": 1.4994,
#                             "y": 1.6853
#                         },
#                         {
#                             "x": 1.4994,
#                             "y": 1.8381
#                         },
#                         {
#                             "x": 0.8978,
#                             "y": 1.8333
#                         }
#                     ],
#                     "span": {
#                         "offset": 42,
#                         "length": 7
#                     },
#                     "confidence": 0.995
#                 },
#                 {
#                     "content": "way",
#                     "polygon": [
#                         {
#                             "x": 1.5281,
#                             "y": 1.6853
#                         },
#                         {
#                             "x": 1.8003,
#                             "y": 1.6806
#                         },
#                         {
#                             "x": 1.8003,
#                             "y": 1.8429
#                         },
#                         {
#                             "x": 1.5329,
#                             "y": 1.8381
#                         }
#                     ],
#                     "span": {
#                         "offset": 50,
#                         "length": 3
#                     },
#                     "confidence": 0.993
#                 },
#                 {
#                     "content": "Suite",
#                     "polygon": [
#                         {
#                             "x": 1.8289,
#                             "y": 1.6806
#                         },
#                         {
#                             "x": 2.1441,
#                             "y": 1.6806
#                         },
#                         {
#                             "x": 2.1441,
#                             "y": 1.8429
#                         },
#                         {
#                             "x": 1.8337,
#                             "y": 1.8429
#                         }
#                     ],
#                     "span": {
#                         "offset": 54,
#                         "length": 5
#                     },
#                     "confidence": 0.993
#                 },
#                 {
#                     "content": "1020",
#                     "polygon": [
#                         {
#                             "x": 5.1955,
#                             "y": 1.6901
#                         },
#                         {
#                             "x": 5.4868,
#                             "y": 1.6901
#                         },
#                         {
#                             "x": 5.4916,
#                             "y": 1.8572
#                         },
#                         {
#                             "x": 5.1955,
#                             "y": 1.8572
#                         }
#                     ],
#                     "span": {
#                         "offset": 60,
#                         "length": 4
#                     },
#                     "confidence": 0.992
#                 },
#                 {
#                     "content": "Enterprise",
#                     "polygon": [
#                         {
#                             "x": 5.5202,
#                             "y": 1.6901
#                         },
#                         {
#                             "x": 6.2126,
#                             "y": 1.6901
#                         },
#                         {
#                             "x": 6.2079,
#                             "y": 1.8668
#                         },
#                         {
#                             "x": 5.525,
#                             "y": 1.8572
#                         }
#                     ],
#                     "span": {
#                         "offset": 65,
#                         "length": 10
#                     },
#                     "confidence": 0.986
#                 },
#                 {
#                     "content": "Way",
#                     "polygon": [
#                         {
#                             "x": 6.2461,
#                             "y": 1.6901
#                         },
#                         {
#                             "x": 6.5421,
#                             "y": 1.6949
#                         },
#                         {
#                             "x": 6.5374,
#                             "y": 1.8668
#                         },
#                         {
#                             "x": 6.2413,
#                             "y": 1.8668
#                         }
#                     ],
#                     "span": {
#                         "offset": 76,
#                         "length": 3
#                     },
#                     "confidence": 0.997
#                 },
#                 {
#                     "content": "6000",
#                     "polygon": [
#                         {
#                             "x": 0.7831,
#                             "y": 1.8715
#                         },
#                         {
#                             "x": 1.0983,
#                             "y": 1.8763
#                         },
#                         {
#                             "x": 1.1031,
#                             "y": 2.0195
#                         },
#                         {
#                             "x": 0.7879,
#                             "y": 2.0195
#                         }
#                     ],
#                     "span": {
#                         "offset": 80,
#                         "length": 4
#                     },
#                     "confidence": 0.993
#                 },
#                 {
#                     "content": "Redmond,",
#                     "polygon": [
#                         {
#                             "x": 1.127,
#                             "y": 1.8763
#                         },
#                         {
#                             "x": 1.7812,
#                             "y": 1.8715
#                         },
#                         {
#                             "x": 1.786,
#                             "y": 2.0243
#                         },
#                         {
#                             "x": 1.1317,
#                             "y": 2.0195
#                         }
#                     ],
#                     "span": {
#                         "offset": 85,
#                         "length": 8
#                     },
#                     "confidence": 0.993
#                 },
#                 {
#                     "content": "WA",
#                     "polygon": [
#                         {
#                             "x": 1.8146,
#                             "y": 1.8715
#                         },
#                         {
#                             "x": 2.0295,
#                             "y": 1.8715
#                         },
#                         {
#                             "x": 2.0295,
#                             "y": 2.0291
#                         },
#                         {
#                             "x": 1.8146,
#                             "y": 2.0291
#                         }
#                     ],
#                     "span": {
#                         "offset": 94,
#                         "length": 2
#                     },
#                     "confidence": 0.995
#                 },
#                 {
#                     "content": "Sunnayvale,",
#                     "polygon": [
#                         {
#                             "x": 5.186,
#                             "y": 1.8811
#                         },
#                         {
#                             "x": 5.9978,
#                             "y": 1.8763
#                         },
#                         {
#                             "x": 5.9978,
#                             "y": 2.0434
#                         },
#                         {
#                             "x": 5.186,
#                             "y": 2.0482
#                         }
#                     ],
#                     "span": {
#                         "offset": 97,
#                         "length": 11
#                     },
#                     "confidence": 0.99
#                 },
#                 {
#                     "content": "CA",
#                     "polygon": [
#                         {
#                             "x": 6.0312,
#                             "y": 1.8763
#                         },
#                         {
#                             "x": 6.2174,
#                             "y": 1.8763
#                         },
#                         {
#                             "x": 6.2174,
#                             "y": 2.0434
#                         },
#                         {
#                             "x": 6.0312,
#                             "y": 2.0434
#                         }
#                     ],
#                     "span": {
#                         "offset": 109,
#                         "length": 2
#                     },
#                     "confidence": 0.995
#                 },
#                 {
#                     "content": "87659",
#                     "polygon": [
#                         {
#                             "x": 6.2604,
#                             "y": 1.8763
#                         },
#                         {
#                             "x": 6.6615,
#                             "y": 1.8763
#                         },
#                         {
#                             "x": 6.6615,
#                             "y": 2.0434
#                         },
#                         {
#                             "x": 6.2604,
#                             "y": 2.0434
#                         }
#                     ],
#                     "span": {
#                         "offset": 112,
#                         "length": 5
#                     },
#                     "confidence": 0.995
#                 },
#                 {
#                     "content": "99243",
#                     "polygon": [
#                         {
#                             "x": 0.7927,
#                             "y": 2.072
#                         },
#                         {
#                             "x": 1.1747,
#                             "y": 2.0673
#                         },
#                         {
#                             "x": 1.1747,
#                             "y": 2.2057
#                         },
#                         {
#                             "x": 0.7975,
#                             "y": 2.2057
#                         }
#                     ],
#                     "span": {
#                         "offset": 118,
#                         "length": 5
#                     },
#                     "confidence": 0.995
#                 },
#                 {
#                     "content": "Invoice",
#                     "polygon": [
#                         {
#                             "x": 0.5205,
#                             "y": 2.8598
#                         },
#                         {
#                             "x": 0.998,
#                             "y": 2.8598
#                         },
#                         {
#                             "x": 0.998,
#                             "y": 2.9935
#                         },
#                         {
#                             "x": 0.5205,
#                             "y": 2.9983
#                         }
#                     ],
#                     "span": {
#                         "offset": 124,
#                         "length": 7
#                     },
#                     "confidence": 0.969
#                 },
#                 {
#                     "content": "Number",
#                     "polygon": [
#                         {
#                             "x": 1.041,
#                             "y": 2.8598
#                         },
#                         {
#                             "x": 1.5758,
#                             "y": 2.855
#                         },
#                         {
#                             "x": 1.5806,
#                             "y": 2.9935
#                         },
#                         {
#                             "x": 1.0458,
#                             "y": 2.9935
#                         }
#                     ],
#                     "span": {
#                         "offset": 132,
#                         "length": 6
#                     },
#                     "confidence": 0.995
#                 },
#                 {
#                     "content": "Invoice",
#                     "polygon": [
#                         {
#                             "x": 1.9292,
#                             "y": 2.855
#                         },
#                         {
#                             "x": 2.4115,
#                             "y": 2.8598
#                         },
#                         {
#                             "x": 2.4115,
#                             "y": 2.9935
#                         },
#                         {
#                             "x": 1.9292,
#                             "y": 2.9935
#                         }
#                     ],
#                     "span": {
#                         "offset": 139,
#                         "length": 7
#                     },
#                     "confidence": 0.985
#                 },
#                 {
#                     "content": "Date",
#                     "polygon": [
#                         {
#                             "x": 2.4545,
#                             "y": 2.8598
#                         },
#                         {
#                             "x": 2.7506,
#                             "y": 2.855
#                         },
#                         {
#                             "x": 2.7506,
#                             "y": 2.9983
#                         },
#                         {
#                             "x": 2.4545,
#                             "y": 2.9935
#                         }
#                     ],
#                     "span": {
#                         "offset": 147,
#                         "length": 4
#                     },
#                     "confidence": 0.993
#                 },
#                 {
#                     "content": "Invoice",
#                     "polygon": [
#                         {
#                             "x": 3.3236,
#                             "y": 2.855
#                         },
#                         {
#                             "x": 3.8059,
#                             "y": 2.8598
#                         },
#                         {
#                             "x": 3.8059,
#                             "y": 2.9935
#                         },
#                         {
#                             "x": 3.3284,
#                             "y": 3.003
#                         }
#                     ],
#                     "span": {
#                         "offset": 152,
#                         "length": 7
#                     },
#                     "confidence": 0.992
#                 },
#                 {
#                     "content": "Due",
#                     "polygon": [
#                         {
#                             "x": 3.8537,
#                             "y": 2.8598
#                         },
#                         {
#                             "x": 4.1067,
#                             "y": 2.855
#                         },
#                         {
#                             "x": 4.1067,
#                             "y": 2.9983
#                         },
#                         {
#                             "x": 3.8537,
#                             "y": 2.9935
#                         }
#                     ],
#                     "span": {
#                         "offset": 160,
#                         "length": 3
#                     },
#                     "confidence": 0.995
#                 },
#                 {
#                     "content": "Date",
#                     "polygon": [
#                         {
#                             "x": 4.1497,
#                             "y": 2.855
#                         },
#                         {
#                             "x": 4.4506,
#                             "y": 2.855
#                         },
#                         {
#                             "x": 4.4506,
#                             "y": 3.0078
#                         },
#                         {
#                             "x": 4.1497,
#                             "y": 2.9983
#                         }
#                     ],
#                     "span": {
#                         "offset": 164,
#                         "length": 4
#                     },
#                     "confidence": 0.993
#                 },
#                 {
#                     "content": "Charges",
#                     "polygon": [
#                         {
#                             "x": 4.7371,
#                             "y": 2.855
#                         },
#                         {
#                             "x": 5.3006,
#                             "y": 2.8598
#                         },
#                         {
#                             "x": 5.3006,
#                             "y": 3.0174
#                         },
#                         {
#                             "x": 4.7371,
#                             "y": 3.0126
#                         }
#                     ],
#                     "span": {
#                         "offset": 169,
#                         "length": 7
#                     },
#                     "confidence": 0.995
#                 },
#                 {
#                     "content": "VAT",
#                     "polygon": [
#                         {
#                             "x": 6.1315,
#                             "y": 2.8598
#                         },
#                         {
#                             "x": 6.418,
#                             "y": 2.855
#                         },
#                         {
#                             "x": 6.4228,
#                             "y": 2.9935
#                         },
#                         {
#                             "x": 6.1362,
#                             "y": 2.9935
#                         }
#                     ],
#                     "span": {
#                         "offset": 177,
#                         "length": 3
#                     },
#                     "confidence": 0.979
#                 },
#                 {
#                     "content": "ID",
#                     "polygon": [
#                         {
#                             "x": 6.4466,
#                             "y": 2.855
#                         },
#                         {
#                             "x": 6.5708,
#                             "y": 2.855
#                         },
#                         {
#                             "x": 6.5708,
#                             "y": 2.9935
#                         },
#                         {
#                             "x": 6.4466,
#                             "y": 2.9935
#                         }
#                     ],
#                     "span": {
#                         "offset": 181,
#                         "length": 2
#                     },
#                     "confidence": 0.995
#                 },
#                 {
#                     "content": "34278587",
#                     "polygon": [
#                         {
#                             "x": 0.5301,
#                             "y": 3.3945
#                         },
#                         {
#                             "x": 1.1508,
#                             "y": 3.3993
#                         },
#                         {
#                             "x": 1.1461,
#                             "y": 3.533
#                         },
#                         {
#                             "x": 0.5301,
#                             "y": 3.5282
#                         }
#                     ],
#                     "span": {
#                         "offset": 184,
#                         "length": 8
#                     },
#                     "confidence": 0.995
#                 },
#                 {
#                     "content": "6/18/2017",
#                     "polygon": [
#                         {
#                             "x": 1.9292,
#                             "y": 3.3898
#                         },
#                         {
#                             "x": 2.5596,
#                             "y": 3.3898
#                         },
#                         {
#                             "x": 2.5596,
#                             "y": 3.533
#                         },
#                         {
#                             "x": 1.934,
#                             "y": 3.533
#                         }
#                     ],
#                     "span": {
#                         "offset": 193,
#                         "length": 9
#                     },
#                     "confidence": 0.994
#                 },
#                 {
#                     "content": "6/24/2017",
#                     "polygon": [
#                         {
#                             "x": 3.3331,
#                             "y": 3.385
#                         },
#                         {
#                             "x": 3.9444,
#                             "y": 3.3802
#                         },
#                         {
#                             "x": 3.9492,
#                             "y": 3.5425
#                         },
#                         {
#                             "x": 3.3284,
#                             "y": 3.5425
#                         }
#                     ],
#                     "span": {
#                         "offset": 203,
#                         "length": 9
#                     },
#                     "confidence": 0.992
#                 },
#                 {
#                     "content": "$56,651.49",
#                     "polygon": [
#                         {
#                             "x": 5.3626,
#                             "y": 3.3898
#                         },
#                         {
#                             "x": 6.0789,
#                             "y": 3.3898
#                         },
#                         {
#                             "x": 6.0837,
#                             "y": 3.5473
#                         },
#                         {
#                             "x": 5.3579,
#                             "y": 3.5569
#                         }
#                     ],
#                     "span": {
#                         "offset": 213,
#                         "length": 10
#                     },
#                     "confidence": 0.962
#                 },
#                 {
#                     "content": "PT",
#                     "polygon": [
#                         {
#                             "x": 6.2079,
#                             "y": 3.3898
#                         },
#                         {
#                             "x": 6.3941,
#                             "y": 3.3898
#                         },
#                         {
#                             "x": 6.3941,
#                             "y": 3.533
#                         },
#                         {
#                             "x": 6.2031,
#                             "y": 3.5282
#                         }
#                     ],
#                     "span": {
#                         "offset": 224,
#                         "length": 2
#                     },
#                     "confidence": 0.995
#                 }
#             ],
#             "selection_marks": [],
#             "spans": [
#                 {
#                     "offset": 0,
#                     "length": 226
#                 }
#             ],
#             "barcodes": [],
#             "formulas": []
#         }
#     ],
#     "paragraphs": [],
#     "tables": [
#         {
#             "row_count": 2,
#             "column_count": 5,
#             "cells": [
#                 {
#                     "kind": "columnHeader",
#                     "row_index": 0,
#                     "column_index": 0,
#                     "row_span": 1,
#                     "column_span": 1,
#                     "content": "Invoice Number",
#                     "bounding_regions": [
#                         {
#                             "page_number": 1,
#                             "polygon": [
#                                 {
#                                     "x": 0.4984,
#                                     "y": 2.7894
#                                 },
#                                 {
#                                     "x": 1.8979,
#                                     "y": 2.7894
#                                 },
#                                 {
#                                     "x": 1.8979,
#                                     "y": 3.3076
#                                 },
#                                 {
#                                     "x": 0.5056,
#                                     "y": 3.3148
#                                 }
#                             ]
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 124,
#                             "length": 14
#                         }
#                     ]
#                 },
#                 {
#                     "kind": "columnHeader",
#                     "row_index": 0,
#                     "column_index": 1,
#                     "row_span": 1,
#                     "column_span": 1,
#                     "content": "Invoice Date",
#                     "bounding_regions": [
#                         {
#                             "page_number": 1,
#                             "polygon": [
#                                 {
#                                     "x": 1.8979,
#                                     "y": 2.7894
#                                 },
#                                 {
#                                     "x": 3.2903,
#                                     "y": 2.7894
#                                 },
#                                 {
#                                     "x": 3.2903,
#                                     "y": 3.3076
#                                 },
#                                 {
#                                     "x": 1.8979,
#                                     "y": 3.3076
#                                 }
#                             ]
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 139,
#                             "length": 12
#                         }
#                     ]
#                 },
#                 {
#                     "kind": "columnHeader",
#                     "row_index": 0,
#                     "column_index": 2,
#                     "row_span": 1,
#                     "column_span": 1,
# ...
#                                 {
#                                     "x": 3.3284,
#                                     "y": 3.5425
#                                 }
#                             ]
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 203,
#                             "length": 9
#                         }
#                     ],
#                     "confidence": 0.989
#                 },
#                 "InvoiceDate": {
#                     "value_type": "date",
#                     "value": "2017-06-18",
#                     "content": "6/18/2017",
#                     "bounding_regions": [
#                         {
#                             "page_number": 1,
#                             "polygon": [
#                                 {
#                                     "x": 1.9292,
#                                     "y": 3.3898
#                                 },
#                                 {
#                                     "x": 2.5596,
#                                     "y": 3.3898
#                                 },
#                                 {
#                                     "x": 2.5596,
#                                     "y": 3.533
#                                 },
#                                 {
#                                     "x": 1.934,
#                                     "y": 3.533
#                                 }
#                             ]
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 193,
#                             "length": 9
#                         }
#                     ],
#                     "confidence": 0.988
#                 },
#                 "InvoiceId": {
#                     "value_type": "string",
#                     "value": "34278587",
#                     "content": "34278587",
#                     "bounding_regions": [
#                         {
#                             "page_number": 1,
#                             "polygon": [
#                                 {
#                                     "x": 0.5301,
#                                     "y": 3.3945
#                                 },
#                                 {
#                                     "x": 1.1508,
#                                     "y": 3.3993
#                                 },
#                                 {
#                                     "x": 1.1461,
#                                     "y": 3.533
#                                 },
#                                 {
#                                     "x": 0.5301,
#                                     "y": 3.5282
#                                 }
#                             ]
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 184,
#                             "length": 8
#                         }
#                     ],
#                     "confidence": 0.987
#                 },
#                 "InvoiceTotal": {
#                     "value_type": "currency",
#                     "value": {
#                         "amount": 56651.49,
#                         "symbol": "$",
#                         "code": "USD"
#                     },
#                     "content": "$56,651.49",
#                     "bounding_regions": [
#                         {
#                             "page_number": 1,
#                             "polygon": [
#                                 {
#                                     "x": 5.3626,
#                                     "y": 3.3898
#                                 },
#                                 {
#                                     "x": 6.0789,
#                                     "y": 3.3898
#                                 },
#                                 {
#                                     "x": 6.0837,
#                                     "y": 3.5473
#                                 },
#                                 {
#                                     "x": 5.3579,
#                                     "y": 3.5569
#                                 }
#                             ]
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 213,
#                             "length": 10
#                         }
#                     ],
#                     "confidence": 0.866
#                 },
#                 "Items": {
#                     "value_type": "list",
#                     "value": [
#                         {
#                             "value_type": "dictionary",
#                             "value": {
#                                 "Amount": {
#                                     "value_type": "currency",
#                                     "value": {
#                                         "amount": 56651.49,
#                                         "symbol": "$",
#                                         "code": "USD"
#                                     },
#                                     "content": "$56,651.49",
#                                     "bounding_regions": [
#                                         {
#                                             "page_number": 1,
#                                             "polygon": [
#                                                 {
#                                                     "x": 5.3626,
#                                                     "y": 3.3898
#                                                 },
#                                                 {
#                                                     "x": 6.0789,
#                                                     "y": 3.3898
#                                                 },
#                                                 {
#                                                     "x": 6.0837,
#                                                     "y": 3.5473
#                                                 },
#                                                 {
#                                                     "x": 5.3579,
#                                                     "y": 3.5569
#                                                 }
#                                             ]
#                                         }
#                                     ],
#                                     "spans": [
#                                         {
#                                             "offset": 213,
#                                             "length": 10
#                                         }
#                                     ],
#                                     "confidence": 0.72
#                                 },
#                                 "Date": {
#                                     "value_type": "date",
#                                     "value": "2017-06-24",
#                                     "content": "6/18/2017\n6/24/2017",
#                                     "bounding_regions": [
#                                         {
#                                             "page_number": 1,
#                                             "polygon": [
#                                                 {
#                                                     "x": 1.9292,
#                                                     "y": 3.3802
#                                                 },
#                                                 {
#                                                     "x": 3.9492,
#                                                     "y": 3.3802
#                                                 },
#                                                 {
#                                                     "x": 3.9492,
#                                                     "y": 3.5425
#                                                 },
#                                                 {
#                                                     "x": 1.9292,
#                                                     "y": 3.5425
#                                                 }
#                                             ]
#                                         }
#                                     ],
#                                     "spans": [
#                                         {
#                                             "offset": 193,
#                                             "length": 19
#                                         }
#                                     ],
#                                     "confidence": 0.703
#                                 },
#                                 "ProductCode": {
#                                     "value_type": "string",
#                                     "value": "34278587",
#                                     "content": "34278587",
#                                     "bounding_regions": [
#                                         {
#                                             "page_number": 1,
#                                             "polygon": [
#                                                 {
#                                                     "x": 0.5301,
#                                                     "y": 3.3945
#                                                 },
#                                                 {
#                                                     "x": 1.1508,
#                                                     "y": 3.3993
#                                                 },
#                                                 {
#                                                     "x": 1.1461,
#                                                     "y": 3.533
#                                                 },
#                                                 {
#                                                     "x": 0.5301,
#                                                     "y": 3.5282
#                                                 }
#                                             ]
#                                         }
#                                     ],
#                                     "spans": [
#                                         {
#                                             "offset": 184,
#                                             "length": 8
#                                         }
#                                     ],
#                                     "confidence": 0.826
#                                 }
#                             },
#                             "content": "34278587\n6/18/2017\n6/24/2017\n$56,651.49\nPT",
#                             "bounding_regions": [
#                                 {
#                                     "page_number": 1,
#                                     "polygon": [
#                                         {
#                                             "x": 0.5301,
#                                             "y": 3.3802
#                                         },
#                                         {
#                                             "x": 6.3941,
#                                             "y": 3.3802
#                                         },
#                                         {
#                                             "x": 6.3941,
#                                             "y": 3.5569
#                                         },
#                                         {
#                                             "x": 0.5301,
#                                             "y": 3.5569
#                                         }
#                                     ]
#                                 }
#                             ],
#                             "spans": [
#                                 {
#                                     "offset": 184,
#                                     "length": 42
#                                 }
#                             ],
#                             "confidence": 0.631
#                         }
#                     ],
#                     "content": null,
#                     "bounding_regions": [],
#                     "spans": [],
#                     "confidence": null
#                 },
#                 "VendorAddress": {
#                     "value_type": "address",
#                     "value": {
#                         "house_number": "1",
#                         "po_box": null,
#                         "road": "Redmond way",
#                         "city": "Redmond",
#                         "state": "WA",
#                         "postal_code": "99243",
#                         "country_region": null,
#                         "street_address": "1 Redmond way Suite\n6000",
#                         "unit": "Suite\n6000",
#                         "city_district": null,
#                         "state_district": null,
#                         "suburb": null,
#                         "house": null,
#                         "level": null
#                     },
#                     "content": "1 Redmond way Suite\n6000 Redmond, WA\n99243",
#                     "bounding_regions": [
#                         {
#                             "page_number": 1,
#                             "polygon": [
#                                 {
#                                     "x": 0.7831,
#                                     "y": 1.6806
#                                 },
#                                 {
#                                     "x": 2.1441,
#                                     "y": 1.6806
#                                 },
#                                 {
#                                     "x": 2.1441,
#                                     "y": 2.2057
#                                 },
#                                 {
#                                     "x": 0.7831,
#                                     "y": 2.2057
#                                 }
#                             ]
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 40,
#                             "length": 19
#                         },
#                         {
#                             "offset": 80,
#                             "length": 16
#                         },
#                         {
#                             "offset": 118,
#                             "length": 5
#                         }
#                     ],
#                     "confidence": 0.995
#                 },
#                 "VendorName": {
#                     "value_type": "string",
#                     "value": "Contoso",
#                     "content": "Contoso",
#                     "bounding_regions": [
#                         {
#                             "page_number": 1,
#                             "polygon": [
#                                 {
#                                     "x": 0.5348,
#                                     "y": 1.1458
#                                 },
#                                 {
#                                     "x": 1.4374,
#                                     "y": 1.1506
#                                 },
#                                 {
#                                     "x": 1.4326,
#                                     "y": 1.375
#                                 },
#                                 {
#                                     "x": 0.5301,
#                                     "y": 1.3798
#                                 }
#                             ]
#                         }
#                     ],
#                     "spans": [
#                         {
#                             "offset": 0,
#                             "length": 7
#                         }
#                     ],
#                     "confidence": 0.342
#                 }
#             },
#             "confidence": 1.0
#         }
#     ]
# }
# --------------JSON Response from Model Ends---------------------
