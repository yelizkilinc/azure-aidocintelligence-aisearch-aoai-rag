# %% [markdown]
# # 04. Azure AI Document Intelligence - Custom Model

# %% [markdown]
# > https://learn.microsoft.com/en-us/azure/ai-services/document-intelligence/overview?view=doc-intel-4.0.0

# %% [markdown]
# ## A. Create an AI Document Intelligence resource and set up environment to run notebook
#
# **_Prerequsite_:** <br>
#
# **AI Document Intelligence resource**: <br>
# To create a AI Document Intelligence resource in your Azure subscription:
# Please follow the steps as specified https://learn.microsoft.com/en-us/azure/ai-services/document-intelligence/create-document-intelligence-resource?view=doc-intel-4.0.0
#
#
# Get your newly created Document Intelligence service in the Azure portal and on the **Keys and Endpoint** page, copy the **Key1** and **Endpoint** values and paste them in the code cell below, replacing **YOUR_FORM_KEY** and **YOUR_FORM_ENDPOINT**.

# %% [markdown]
# **Environment: **
#
# 1. **AML workspace**: Please ensure you have Python 3.10 version or above ie select **Python 3.10 - SDK v2** as kernel in AML Notebook. <br>
# 2. **VS Code**: Please select Python **Python 3.10** above or try to set up virtual envi by following steps https://code.visualstudio.com/docs/python/environments
#
# Please skip this step if you are already done it

# %% [markdown]
# ## B. Install AI Doc Intelligence library

# %%
# install azure-ai-formrecognizer python library and restart the kernal after installation
# ignore this step is you have already installed azure-ai-formrecognizer python library
# %pip install azure-ai-formrecognizer --upgrade --user
# Out:
# Requirement already satisfied: azure-ai-formrecognizer in /home/azureuser/.local/lib/python3.10/site-packages (3.3.3)
# Requirement already satisfied: azure-core>=1.23.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-ai-formrecognizer) (1.27.1)
# Requirement already satisfied: msrest>=0.6.21 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-ai-formrecognizer) (0.7.1)
# Requirement already satisfied: azure-common>=1.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-ai-formrecognizer) (1.1.28)
# Requirement already satisfied: typing-extensions>=4.0.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-ai-formrecognizer) (4.6.3)
# Requirement already satisfied: requests>=2.18.4 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-core>=1.23.0->azure-ai-formrecognizer) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-core>=1.23.0->azure-ai-formrecognizer) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (2023.5.7)
# Requirement already satisfied: isodate>=0.6.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.18.4->azure-core>=1.23.0->azure-ai-formrecognizer) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.18.4->azure-core>=1.23.0->azure-ai-formrecognizer) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.18.4->azure-core>=1.23.0->azure-ai-formrecognizer) (1.26.16)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-formrecognizer) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## C. Build custom model
#
# - Please follow the steps to create custom model https://learn.microsoft.com/en-us/azure/ai-services/document-intelligence/how-to-guides/build-a-custom-model?view=doc-intel-4.0.0
# - Sample docs are available to build custom model at https://dev.azure.com/datasciencesquad/ai-bootcamp-2024/_git/week2-search-formrecognizer-app-agents?path=/Day2/AI-Doc-Intelligence-Sample-Files <br>
# - Upload the sample documents to train ie label the documents and use the one of the sample file to test the model <br>

# %% [markdown]
# ## D. Setting up AI Doc Intelligence endpoint, key and custom model id

# %%
# Import the os module for interacting with the operating system
import os
# Import for handling resource not found errors
from azure.core.exceptions import ResourceNotFoundError
# Import for authenticating with the Azure service
from azure.core.credentials import AzureKeyCredential
# Import for analysing forms
from azure.ai.formrecognizer import DocumentAnalysisClient, AnalyzeResult

# set `<your-endpoint>` and `<your-key>` variables with the values from the Azure portal
END_POINT = "XXXX"
END_POINT_KEY = "XXXX"
# custom model id that you have created
CUSTOM_MODEL_ID = "XXXX"

# create form recognizer client
form_recognizer_client = DocumentAnalysisClient(END_POINT, AzureKeyCredential(END_POINT_KEY))

# %% [markdown]
# ## E. Extract the document insights using custom model

# %%
# sample document
# You can change the URL pointing to your sample custom docs but ensure you provide appropriate access
# sample documents available in the following page https://dev.azure.com/datasciencesquad/ai-bootcamp-2024/_git/week2-search-formrecognizer-app-agents?path=/Day2/AI-Doc-Intelligence-Sample-Files to train and create custom model
# make sure you enable at least read only access for the doc from your storage container account
sampleUrl = "XXX"

poller = form_recognizer_client.begin_analyze_document_from_url(CUSTOM_MODEL_ID,sampleUrl)
print(poller)

result = poller.result()

print(result.documents)

for idx, document in enumerate(result.documents):
    print(f"--------Analyzing document #{idx + 1}--------")
    print(f"Document has type {document.doc_type}")
    print(f"Document has document type confidence {document.confidence}")
    print(f"Document was analyzed with model with ID {result.model_id}")
    for name, field in document.fields.items():
        field_value = field.value if field.value else field.content
        print(
            f"......found field of type '{field.value_type}' with value '{field_value}' and with confidence {field.confidence}"
        )

# iterate over tables, lines, and selection marks on each page
for page in result.pages:
    print(f"\nLines found on page {page.page_number}")
    for line in page.lines:
        print(f"...Line '{line.content}'")
    for word in page.words:
        print(f"...Word '{word.content}' has a confidence of {word.confidence}")
    if page.selection_marks:
        print(f"\nSelection marks found on page {page.page_number}")
        for selection_mark in page.selection_marks:
            print(
                f"...Selection mark is '{selection_mark.state}' and has a confidence of {selection_mark.confidence}"
            )

for i, table in enumerate(result.tables):
    print(f"\nTable {i + 1} can be found on page:")
    for region in table.bounding_regions:
        print(f"...{region.page_number}")
    for cell in table.cells:
        print(
            f"...Cell[{cell.row_index}][{cell.column_index}] has text '{cell.content}'"
        )
# Out:
# <azure.core.polling._poller.LROPoller object at 0x7fdccf51c160>
# [AnalyzedDocument(doc_type=customreceiptlrl, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=0.0, y=0.0), Point(x=8.2639, y=0.0), Point(x=8.2639, y=11.6806), Point(x=0.0, y=11.6806)]), BoundingRegion(page_number=2, polygon=[Point(x=0.0, y=0.0), Point(x=8.2639, y=0.0), Point(x=8.2639, y=11.6806), Point(x=0.0, y=11.6806)]), BoundingRegion(page_number=3, polygon=[Point(x=0.0, y=0.0), Point(x=8.2639, y=0.0), Point(x=8.2639, y=11.6806), Point(x=0.0, y=11.6806)]), BoundingRegion(page_number=4, polygon=[Point(x=0.0, y=0.0), Point(x=8.2639, y=0.0), Point(x=8.2639, y=11.6806), Point(x=0.0, y=11.6806)]), BoundingRegion(page_number=5, polygon=[Point(x=0.0, y=0.0), Point(x=8.2639, y=0.0), Point(x=8.2639, y=11.6806), Point(x=0.0, y=11.6806)]), BoundingRegion(page_number=6, polygon=[Point(x=0.0, y=0.0), Point(x=8.2639, y=0.0), Point(x=8.2639, y=11.6806), Point(x=0.0, y=11.6806)]), BoundingRegion(page_number=7, polygon=[Point(x=0.0, y=0.0), Point(x=8.2639, y=0.0), Point(x=8.2639, y=11.6806), Point(x=0.0, y=11.6806)]), BoundingRegion(page_number=8, polygon=[Point(x=0.0, y=0.0), Point(x=8.2639, y=0.0), Point(x=8.2639, y=11.6806), Point(x=0.0, y=11.6806)]), BoundingRegion(page_number=9, polygon=[Point(x=0.0, y=0.0), Point(x=8.2639, y=0.0), Point(x=8.2639, y=11.6806), Point(x=0.0, y=11.6806)]), BoundingRegion(page_number=10, polygon=[Point(x=0.0, y=0.0), Point(x=8.2639, y=0.0), Point(x=8.2639, y=11.6806), Point(x=0.0, y=11.6806)])], spans=[DocumentSpan(offset=0, length=23384)], fields={'InvoiceDate': DocumentField(value_type=date, value=None, content=March 31, 2020, bounding_regions=[BoundingRegion(page_number=1, polygon=[Point(x=2.7783, y=1.7643), Point(x=3.6909, y=1.7643), Point(x=3.6909, y=1.9214), Point(x=2.7783, y=1.9214)])], spans=[DocumentSpan(offset=132, length=14)], confidence=0.247), 'Total': DocumentField(value_type=float, value=None, content=285,449, bounding_regions=[BoundingRegion(page_number=5, polygon=[Point(x=6.1143, y=7.2268), Point(x=6.5612, y=7.2294), Point(x=6.5604, y=7.3663), Point(x=6.1135, y=7.3637)])], spans=[DocumentSpan(offset=7221, length=7)], confidence=0.127), 'Items': DocumentField(value_type=list, value=[], content=None, bounding_regions=[], spans=[], confidence=None), 'ServiceEndDate': DocumentField(value_type=date, value=None, content=None, bounding_regions=[], spans=[], confidence=0.727), 'CustomerAddress': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.79), 'VendorAddressRecipient': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.791), 'TransactionTime': DocumentField(value_type=time, value=None, content=None, bounding_regions=[], spans=[], confidence=0.727), 'CustomerName': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.711), 'VendorName': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.614), 'Tip': DocumentField(value_type=float, value=None, content=None, bounding_regions=[], spans=[], confidence=0.878), 'TransactionDate': DocumentField(value_type=date, value=None, content=None, bounding_regions=[], spans=[], confidence=0.48), 'MerchantAddress': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.494), 'ServiceStartDate': DocumentField(value_type=date, value=None, content=None, bounding_regions=[], spans=[], confidence=0.792), 'MerchantName': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.423), 'CustomerAddressRecipient': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.792), 'TotalTax': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence=0.792), 'MerchantPhoneNumber': DocumentField(value_type=string, value=None, content=None, bounding_regions=[], spans=[], confidence ...
# --------Analyzing document #1--------
# Document has type customreceiptlrl
# Document has document type confidence 0.001
# Document was analyzed with model with ID customreceiptlrl
# ......found field of type 'date' with value 'March 31, 2020' and with confidence 0.247
# ......found field of type 'float' with value '285,449' and with confidence 0.127
# ......found field of type 'list' with value 'None' and with confidence None
# ......found field of type 'date' with value 'None' and with confidence 0.727
# ......found field of type 'string' with value 'None' and with confidence 0.79
# ......found field of type 'string' with value 'None' and with confidence 0.791
# ......found field of type 'time' with value 'None' and with confidence 0.727
# ......found field of type 'string' with value 'None' and with confidence 0.711
# ......found field of type 'string' with value 'None' and with confidence 0.614
# ......found field of type 'float' with value 'None' and with confidence 0.878
# ......found field of type 'date' with value 'None' and with confidence 0.48
# ......found field of type 'string' with value 'None' and with confidence 0.494
# ......found field of type 'date' with value 'None' and with confidence 0.792
# ......found field of type 'string' with value 'None' and with confidence 0.423
# ......found field of type 'string' with value 'None' and with confidence 0.792
# ......found field of type 'string' with value 'None' and with confidence 0.792
# ......found field of type 'string' with value 'None' and with confidence 0.693
# ......found field of type 'float' with value 'None' and with confidence 0.882
# ......found field of type 'string' with value 'None' and with confidence 0.762
#
# Lines found on page 1
# ...Line '☒'
# ...Line 'QUARTERLY REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF'
# ...Line '1934 For the Quarterly Period Ended March 31, 2020'
# ...Line 'UNITED STATES'
# ...Line 'SECURITIES AND EXCHANGE COMMISSION'
# ...Line 'Washington, D.C. 20549'
# ...Line 'FORM 10-Q'
# ...Line 'OR'
# ...Line '☐'
# ...Line 'TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934'
# ...Line 'For the Transition Period From'
# ...Line 'to'
# ...Line 'Commission File Number 001-37845'
# ...Line 'MICROSOFT CORPORATION'
# ...Line 'WASHINGTON'
# ...Line '(STATE OF INCORPORATION)'
# ...Line 'ONE MICROSOFT WAY, REDMOND, WASHINGTON 98052-6399'
# ...Line '(425) 882-8080'
# ...Line 'www.microsoft.com/investor'
# ...Line '91-1144442'
# ...Line '(I.R.S. ID)'
# ...Line 'Securities registered pursuant to Section 12(b) of the Act:'
# ...Line 'Title of each class'
# ...Line 'Trading Symbol'
# ...Line 'Name of exchange on which registered'
# ...Line 'Common stock, $0.00000625 par value per share'
# ...Line 'MSFT'
# ...Line 'NASDAQ'
# ...Line '2.125% Notes due 2021'
# ...Line 'MSFT'
# ...Line 'NASDAQ'
# ...Line '3.125% Notes due 2028'
# ...Line 'MSFT'
# ...Line 'NASDAQ'
# ...Line '2.625% Notes due 2033'
# ...Line 'MSFT'
# ...Line 'NASDAQ'
# ...Line 'Securities registered pursuant to Section 12(g) of the Act:'
# ...Line 'NONE'
# ...Line 'Indicate by check mark whether the registrant (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during the'
# ...Line 'preceding 12 months (or for such shorter period that the registrant was required to file such reports), and (2) has been subject to such filing requirements for the past 90'
# ...Line 'days. Yes'
# ...Line 'No'
# ...Line 'Indicate by check mark whether the registrant has submitted electronically every Interactive Data File required to be submitted pursuant to Rule 405 of Regulation S-T'
# ...Line '(§232.405 of this chapter) during the preceding 12 months (or for such shorter period that the registrant was required to submit such files). Yes'
# ...Line 'X No'
# ...Line 'Indicate by check mark whether the registrant is a large accelerated filer, an accelerated filer, a non-accelerated filer, a smaller reporting company, or an emerging'
# ...Line 'growth company. See the definitions of "large accelerated filer," "accelerated filer," "smaller reporting company," and "emerging growth company" in Rule 12b-2 of the'
# ...Line 'Exchange Act.'
# ...Line 'X'
# ...Line 'Large accelerated filer'
# ...Line 'Accelerated filer'
# ...Line 'Non-accelerated filer'
# ...Line 'Smaller reporting company'
# ...Line 'Emerging growth company'
# ...Line 'If an emerging growth company, indicate by check mark if the registrant has elected not to use the extended transition period for complying with any new or revised'
# ...Line 'financial accounting standards provided pursuant to Section 13(a) of the Exchange Act.'
# ...Line 'Indicate by check mark whether the registrant is a shell company (as defined in Rule 12b-2 of the Exchange Act). Yes'
# ...Line 'No'
# ...Line 'Indicate the number of shares outstanding of each of the issuer's classes of common stock, as of the latest practicable date.'
# ...Line 'Class'
# ...Line 'Outstanding as of April 24, 2020'
# ...Line 'Common Stock, $0.00000625 par value per share'
# ...Line '7,583,440,247 shares'
# ...Word '☒' has a confidence of 1.0
# ...Word 'QUARTERLY' has a confidence of 0.994
# ...Word 'REPORT' has a confidence of 0.995
# ...Word 'PURSUANT' has a confidence of 0.993
# ...Word 'TO' has a confidence of 0.996
# ...Word 'SECTION' has a confidence of 0.993
# ...Word '13' has a confidence of 0.995
# ...Word 'OR' has a confidence of 0.995
# ...Word '15(d)' has a confidence of 0.951
# ...Word 'OF' has a confidence of 0.996
# ...Word 'THE' has a confidence of 0.996
# ...Word 'SECURITIES' has a confidence of 0.983
# ...Word 'EXCHANGE' has a confidence of 0.993
# ...Word 'ACT' has a confidence of 0.981
# ...Word 'OF' has a confidence of 0.996
# ...Word '1934' has a confidence of 0.991
# ...Word 'For' has a confidence of 0.996
# ...Word 'the' has a confidence of 0.996
# ...Word 'Quarterly' has a confidence of 0.993
# ...Word 'Period' has a confidence of 0.995
# ...Word 'Ended' has a confidence of 0.993
# ...Word 'March' has a confidence of 0.961
# ...Word '31,' has a confidence of 0.995
# ...Word '2020' has a confidence of 0.992
# ...Word 'UNITED' has a confidence of 0.995
# ...Word 'STATES' has a confidence of 0.994
# ...Word 'SECURITIES' has a confidence of 0.99
# ...Word 'AND' has a confidence of 0.997
# ...Word 'EXCHANGE' has a confidence of 0.995
# ...Word 'COMMISSION' has a confidence of 0.983
# ...Word 'Washington,' has a confidence of 0.992
# ...Word 'D.C.' has a confidence of 0.993
# ...Word '20549' has a confidence of 0.995
# ...Word 'FORM' has a confidence of 0.993
# ...Word '10-Q' has a confidence of 0.993
# ...Word 'OR' has a confidence of 0.993
# ...Word '☐' has a confidence of 1.0
# ...Word 'TRANSITION' has a confidence of 0.992
# ...Word 'REPORT' has a confidence of 0.994
# ...Word 'PURSUANT' has a confidence of 0.992
# ...Word 'TO' has a confidence of 0.995
# ...Word 'SECTION' has a confidence of 0.993
# ...Word '13' has a confidence of 0.995
# ...Word 'OR' has a confidence of 0.995
# ...Word '15(d)' has a confidence of 0.99
# ...Word 'OF' has a confidence of 0.996
# ...Word 'THE' has a confidence of 0.996
# ...Word 'SECURITIES' has a confidence of 0.993
# ...Word 'EXCHANGE' has a confidence of 0.993
# ...Word 'ACT' has a confidence of 0.996
# ...Word 'OF' has a confidence of 0.995
# ...Word '1934' has a confidence of 0.986
# ...Word 'For' has a confidence of 0.996
# ...Word 'the' has a confidence of 0.996
# ...Word 'Transition' has a confidence of 0.993
# ...Word 'Period' has a confidence of 0.994
# ...Word 'From' has a confidence of 0.993
# ...Word 'to' has a confidence of 0.996
# ...Word 'Commission' has a confidence of 0.993
# ...Word 'File' has a confidence of 0.983
# ...Word 'Number' has a confidence of 0.994
# ...Word '001-37845' has a confidence of 0.994
# ...Word 'MICROSOFT' has a confidence of 0.995
# ...Word 'CORPORATION' has a confidence of 0.993
# ...Word 'WASHINGTON' has a confidence of 0.993
# ...Word '(STATE' has a confidence of 0.994
# ...Word 'OF' has a confidence of 0.996
# ...Word 'INCORPORATION)' has a confidence of 0.989
# ...Word 'ONE' has a confidence of 0.993
# ...Word 'MICROSOFT' has a confidence of 0.995
# ...Word 'WAY,' has a confidence of 0.992
# ...Word 'REDMOND,' has a confidence of 0.994
# ...Word 'WASHINGTON' has a confidence of 0.994
# ...Word '98052-6399' has a confidence of 0.993
# ...Word '(425)' has a confidence of 0.995
# ...Word '882-8080' has a confidence of 0.994
# ...Word 'www.microsoft.com/investor' has a confidence of 0.962
# ...Word '91-1144442' has a confidence of 0.993
# ...Word '(I.R.S.' has a confidence of 0.931
# ...Word 'ID)' has a confidence of 0.995
# ...Word 'Securities' has a confidence of 0.976
# ...Word 'registered' has a confidence of 0.914
# ...Word 'pursuant' has a confidence of 0.98
# ...Word 'to' has a confidence of 0.995
# ...Word 'Section' has a confidence of 0.992
# ...Word '12(b)' has a confidence of 0.99
# ...Word 'of' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.996
# ...Word 'Act:' has a confidence of 0.973
# ...Word 'Title' has a confidence of 0.995
# ...Word 'of' has a confidence of 0.995
# ...Word 'each' has a confidence of 0.993
# ...Word 'class' has a confidence of 0.995
# ...Word 'Trading' has a confidence of 0.995
# ...Word 'Symbol' has a confidence of 0.995
# ...Word 'Name' has a confidence of 0.982
# ...Word 'of' has a confidence of 0.996
# ...Word 'exchange' has a confidence of 0.994
# ...Word 'on' has a confidence of 0.997
# ...Word 'which' has a confidence of 0.995
# ...Word 'registered' has a confidence of 0.993
# ...Word 'Common' has a confidence of 0.995
# ...Word 'stock,' has a confidence of 0.993
# ...Word '$0.00000625' has a confidence of 0.991
# ...Word 'par' has a confidence of 0.995
# ...Word 'value' has a confidence of 0.995
# ...Word 'per' has a confidence of 0.996
# ...Word 'share' has a confidence of 0.995
# ...Word 'MSFT' has a confidence of 0.992
# ...Word 'NASDAQ' has a confidence of 0.995
# ...Word '2.125%' has a confidence of 0.961
# ...Word 'Notes' has a confidence of 0.995
# ...Word 'due' has a confidence of 0.995
# ...Word '2021' has a confidence of 0.992
# ...Word 'MSFT' has a confidence of 0.991
# ...Word 'NASDAQ' has a confidence of 0.995
# ...Word '3.125%' has a confidence of 0.981
# ...Word 'Notes' has a confidence of 0.994
# ...Word 'due' has a confidence of 0.995
# ...Word '2028' has a confidence of 0.992
# ...Word 'MSFT' has a confidence of 0.991
# ...Word 'NASDAQ' has a confidence of 0.992
# ...Word '2.625%' has a confidence of 0.995
# ...Word 'Notes' has a confidence of 0.993
# ...Word 'due' has a confidence of 0.99
# ...Word '2033' has a confidence of 0.991
# ...Word 'MSFT' has a confidence of 0.991
# ...Word 'NASDAQ' has a confidence of 0.995
# ...Word 'Securities' has a confidence of 0.972
# ...Word 'registered' has a confidence of 0.964
# ...Word 'pursuant' has a confidence of 0.99
# ...Word 'to' has a confidence of 0.995
# ...Word 'Section' has a confidence of 0.987
# ...Word '12(g)' has a confidence of 0.966
# ...Word 'of' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.995
# ...Word 'Act:' has a confidence of 0.979
# ...Word 'NONE' has a confidence of 0.992
# ...Word 'Indicate' has a confidence of 0.98
# ...Word 'by' has a confidence of 0.995
# ...Word 'check' has a confidence of 0.994
# ...Word 'mark' has a confidence of 0.992
# ...Word 'whether' has a confidence of 0.993
# ...Word 'the' has a confidence of 0.995
# ...Word 'registrant' has a confidence of 0.972
# ...Word '(1)' has a confidence of 0.989
# ...Word 'has' has a confidence of 0.995
# ...Word 'filed' has a confidence of 0.993
# ...Word 'all' has a confidence of 0.995
# ...Word 'reports' has a confidence of 0.988
# ...Word 'required' has a confidence of 0.982
# ...Word 'to' has a confidence of 0.995
# ...Word 'be' has a confidence of 0.9
# ...Word 'filed' has a confidence of 0.993
# ...Word 'by' has a confidence of 0.995
# ...Word 'Section' has a confidence of 0.993
# ...Word '13' has a confidence of 0.995
# ...Word 'or' has a confidence of 0.995
# ...Word '15(d)' has a confidence of 0.99
# ...Word 'of' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.995
# ...Word 'Securities' has a confidence of 0.982
# ...Word 'Exchange' has a confidence of 0.995
# ...Word 'Act' has a confidence of 0.995
# ...Word 'of' has a confidence of 0.995
# ...Word '1934' has a confidence of 0.991
# ...Word 'during' has a confidence of 0.994
# ...Word 'the' has a confidence of 0.995
# ...Word 'preceding' has a confidence of 0.992
# ...Word '12' has a confidence of 0.995
# ...Word 'months' has a confidence of 0.993
# ...Word '(or' has a confidence of 0.995
# ...Word 'for' has a confidence of 0.995
# ...Word 'such' has a confidence of 0.992
# ...Word 'shorter' has a confidence of 0.993
# ...Word 'period' has a confidence of 0.993
# ...Word 'that' has a confidence of 0.992
# ...Word 'the' has a confidence of 0.993
# ...Word 'registrant' has a confidence of 0.984
# ...Word 'was' has a confidence of 0.995
# ...Word 'required' has a confidence of 0.98
# ...Word 'to' has a confidence of 0.995
# ...Word 'file' has a confidence of 0.99
# ...Word 'such' has a confidence of 0.992
# ...Word 'reports),' has a confidence of 0.961
# ...Word 'and' has a confidence of 0.995
# ...Word '(2)' has a confidence of 0.979
# ...Word 'has' has a confidence of 0.995
# ...Word 'been' has a confidence of 0.992
# ...Word 'subject' has a confidence of 0.993
# ...Word 'to' has a confidence of 0.995
# ...Word 'such' has a confidence of 0.992
# ...Word 'filing' has a confidence of 0.981
# ...Word 'requirements' has a confidence of 0.983
# ...Word 'for' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.996
# ...Word 'past' has a confidence of 0.993
# ...Word '90' has a confidence of 0.994
# ...Word 'days.' has a confidence of 0.994
# ...Word 'Yes' has a confidence of 0.995
# ...Word 'No' has a confidence of 0.995
# ...Word 'Indicate' has a confidence of 0.985
# ...Word 'by' has a confidence of 0.995
# ...Word 'check' has a confidence of 0.995
# ...Word 'mark' has a confidence of 0.992
# ...Word 'whether' has a confidence of 0.994
# ...Word 'the' has a confidence of 0.996
# ...Word 'registrant' has a confidence of 0.987
# ...Word 'has' has a confidence of 0.995
# ...Word 'submitted' has a confidence of 0.978
# ...Word 'electronically' has a confidence of 0.974
# ...Word 'every' has a confidence of 0.944
# ...Word 'Interactive' has a confidence of 0.961
# ...Word 'Data' has a confidence of 0.991
# ...Word 'File' has a confidence of 0.992
# ...Word 'required' has a confidence of 0.988
# ...Word 'to' has a confidence of 0.995
# ...Word 'be' has a confidence of 0.995
# ...Word 'submitted' has a confidence of 0.98
# ...Word 'pursuant' has a confidence of 0.985
# ...Word 'to' has a confidence of 0.995
# ...Word 'Rule' has a confidence of 0.991
# ...Word '405' has a confidence of 0.995
# ...Word 'of' has a confidence of 0.995
# ...Word 'Regulation' has a confidence of 0.983
# ...Word 'S-T' has a confidence of 0.995
# ...Word '(§232.405' has a confidence of 0.982
# ...Word 'of' has a confidence of 0.995
# ...Word 'this' has a confidence of 0.992
# ...Word 'chapter)' has a confidence of 0.993
# ...Word 'during' has a confidence of 0.994
# ...Word 'the' has a confidence of 0.995
# ...Word 'preceding' has a confidence of 0.982
# ...Word '12' has a confidence of 0.994
# ...Word 'months' has a confidence of 0.993
# ...Word '(or' has a confidence of 0.995
# ...Word 'for' has a confidence of 0.996
# ...Word 'such' has a confidence of 0.992
# ...Word 'shorter' has a confidence of 0.993
# ...Word 'period' has a confidence of 0.993
# ...Word 'that' has a confidence of 0.992
# ...Word 'the' has a confidence of 0.997
# ...Word 'registrant' has a confidence of 0.992
# ...Word 'was' has a confidence of 0.994
# ...Word 'required' has a confidence of 0.993
# ...Word 'to' has a confidence of 0.995
# ...Word 'submit' has a confidence of 0.99
# ...Word 'such' has a confidence of 0.991
# ...Word 'files).' has a confidence of 0.933
# ...Word 'Yes' has a confidence of 0.995
# ...Word 'X' has a confidence of 0.552
# ...Word 'No' has a confidence of 0.995
# ...Word 'Indicate' has a confidence of 0.974
# ...Word 'by' has a confidence of 0.995
# ...Word 'check' has a confidence of 0.995
# ...Word 'mark' has a confidence of 0.993
# ...Word 'whether' has a confidence of 0.994
# ...Word 'the' has a confidence of 0.996
# ...Word 'registrant' has a confidence of 0.992
# ...Word 'is' has a confidence of 0.995
# ...Word 'a' has a confidence of 0.995
# ...Word 'large' has a confidence of 0.993
# ...Word 'accelerated' has a confidence of 0.99
# ...Word 'filer,' has a confidence of 0.993
# ...Word 'an' has a confidence of 0.996
# ...Word 'accelerated' has a confidence of 0.991
# ...Word 'filer,' has a confidence of 0.992
# ...Word 'a' has a confidence of 0.995
# ...Word 'non-accelerated' has a confidence of 0.983
# ...Word 'filer,' has a confidence of 0.991
# ...Word 'a' has a confidence of 0.995
# ...Word 'smaller' has a confidence of 0.993
# ...Word 'reporting' has a confidence of 0.983
# ...Word 'company,' has a confidence of 0.961
# ...Word 'or' has a confidence of 0.996
# ...Word 'an' has a confidence of 0.997
# ...Word 'emerging' has a confidence of 0.993
# ...Word 'growth' has a confidence of 0.995
# ...Word 'company.' has a confidence of 0.993
# ...Word 'See' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.995
# ...Word 'definitions' has a confidence of 0.964
# ...Word 'of' has a confidence of 0.995
# ...Word '"large' has a confidence of 0.947
# ...Word 'accelerated' has a confidence of 0.982
# ...Word 'filer,"' has a confidence of 0.944
# ...Word '"accelerated' has a confidence of 0.948
# ...Word 'filer,"' has a confidence of 0.916
# ...Word '"smaller' has a confidence of 0.972
# ...Word 'reporting' has a confidence of 0.989
# ...Word 'company,"' has a confidence of 0.929
# ...Word 'and' has a confidence of 0.995
# ...Word '"emerging' has a confidence of 0.936
# ...Word 'growth' has a confidence of 0.994
# ...Word 'company"' has a confidence of 0.948
# ...Word 'in' has a confidence of 0.995
# ...Word 'Rule' has a confidence of 0.991
# ...Word '12b-2' has a confidence of 0.989
# ...Word 'of' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.996
# ...Word 'Exchange' has a confidence of 0.995
# ...Word 'Act.' has a confidence of 0.989
# ...Word 'X' has a confidence of 0.816
# ...Word 'Large' has a confidence of 0.995
# ...Word 'accelerated' has a confidence of 0.993
# ...Word 'filer' has a confidence of 0.995
# ...Word 'Accelerated' has a confidence of 0.993
# ...Word 'filer' has a confidence of 0.995
# ...Word 'Non-accelerated' has a confidence of 0.983
# ...Word 'filer' has a confidence of 0.995
# ...Word 'Smaller' has a confidence of 0.995
# ...Word 'reporting' has a confidence of 0.994
# ...Word 'company' has a confidence of 0.995
# ...Word 'Emerging' has a confidence of 0.994
# ...Word 'growth' has a confidence of 0.995
# ...Word 'company' has a confidence of 0.995
# ...Word 'If' has a confidence of 0.973
# ...Word 'an' has a confidence of 0.995
# ...Word 'emerging' has a confidence of 0.993
# ...Word 'growth' has a confidence of 0.995
# ...Word 'company,' has a confidence of 0.992
# ...Word 'indicate' has a confidence of 0.992
# ...Word 'by' has a confidence of 0.96
# ...Word 'check' has a confidence of 0.993
# ...Word 'mark' has a confidence of 0.989
# ...Word 'if' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.996
# ...Word 'registrant' has a confidence of 0.991
# ...Word 'has' has a confidence of 0.995
# ...Word 'elected' has a confidence of 0.993
# ...Word 'not' has a confidence of 0.995
# ...Word 'to' has a confidence of 0.996
# ...Word 'use' has a confidence of 0.994
# ...Word 'the' has a confidence of 0.996
# ...Word 'extended' has a confidence of 0.993
# ...Word 'transition' has a confidence of 0.98
# ...Word 'period' has a confidence of 0.991
# ...Word 'for' has a confidence of 0.949
# ...Word 'complying' has a confidence of 0.993
# ...Word 'with' has a confidence of 0.993
# ...Word 'any' has a confidence of 0.996
# ...Word 'new' has a confidence of 0.996
# ...Word 'or' has a confidence of 0.996
# ...Word 'revised' has a confidence of 0.994
# ...Word 'financial' has a confidence of 0.983
# ...Word 'accounting' has a confidence of 0.993
# ...Word 'standards' has a confidence of 0.991
# ...Word 'provided' has a confidence of 0.992
# ...Word 'pursuant' has a confidence of 0.977
# ...Word 'to' has a confidence of 0.995
# ...Word 'Section' has a confidence of 0.993
# ...Word '13(a)' has a confidence of 0.989
# ...Word 'of' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.994
# ...Word 'Exchange' has a confidence of 0.994
# ...Word 'Act.' has a confidence of 0.981
# ...Word 'Indicate' has a confidence of 0.969
# ...Word 'by' has a confidence of 0.995
# ...Word 'check' has a confidence of 0.994
# ...Word 'mark' has a confidence of 0.99
# ...Word 'whether' has a confidence of 0.994
# ...Word 'the' has a confidence of 0.995
# ...Word 'registrant' has a confidence of 0.99
# ...Word 'is' has a confidence of 0.995
# ...Word 'a' has a confidence of 0.995
# ...Word 'shell' has a confidence of 0.994
# ...Word 'company' has a confidence of 0.995
# ...Word '(as' has a confidence of 0.961
# ...Word 'defined' has a confidence of 0.975
# ...Word 'in' has a confidence of 0.995
# ...Word 'Rule' has a confidence of 0.991
# ...Word '12b-2' has a confidence of 0.991
# ...Word 'of' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.995
# ...Word 'Exchange' has a confidence of 0.994
# ...Word 'Act).' has a confidence of 0.977
# ...Word 'Yes' has a confidence of 0.961
# ...Word 'No' has a confidence of 0.995
# ...Word 'Indicate' has a confidence of 0.982
# ...Word 'the' has a confidence of 0.996
# ...Word 'number' has a confidence of 0.985
# ...Word 'of' has a confidence of 0.995
# ...Word 'shares' has a confidence of 0.995
# ...Word 'outstanding' has a confidence of 0.991
# ...Word 'of' has a confidence of 0.995
# ...Word 'each' has a confidence of 0.993
# ...Word 'of' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.989
# ...Word 'issuer's' has a confidence of 0.993
# ...Word 'classes' has a confidence of 0.993
# ...Word 'of' has a confidence of 0.995
# ...Word 'common' has a confidence of 0.995
# ...Word 'stock,' has a confidence of 0.992
# ...Word 'as' has a confidence of 0.995
# ...Word 'of' has a confidence of 0.996
# ...Word 'the' has a confidence of 0.996
# ...Word 'latest' has a confidence of 0.993
# ...Word 'practicable' has a confidence of 0.99
# ...Word 'date.' has a confidence of 0.993
# ...Word 'Class' has a confidence of 0.995
# ...Word 'Outstanding' has a confidence of 0.988
# ...Word 'as' has a confidence of 0.995
# ...Word 'of' has a confidence of 0.996
# ...Word 'April' has a confidence of 0.995
# ...Word '24,' has a confidence of 0.994
# ...Word '2020' has a confidence of 0.992
# ...Word 'Common' has a confidence of 0.995
# ...Word 'Stock,' has a confidence of 0.993
# ...Word '$0.00000625' has a confidence of 0.991
# ...Word 'par' has a confidence of 0.996
# ...Word 'value' has a confidence of 0.995
# ...Word 'per' has a confidence of 0.995
# ...Word 'share' has a confidence of 0.995
# ...Word '7,583,440,247' has a confidence of 0.991
# ...Word 'shares' has a confidence of 0.995
#
# Selection marks found on page 1
# ...Selection mark is 'selected' and has a confidence of 0.99
# ...Selection mark is 'unselected' and has a confidence of 0.977
# ...Selection mark is 'selected' and has a confidence of 0.993
# ...Selection mark is 'unselected' and has a confidence of 0.98
# ...Selection mark is 'selected' and has a confidence of 0.995
# ...Selection mark is 'unselected' and has a confidence of 0.993
# ...Selection mark is 'selected' and has a confidence of 0.99
# ...Selection mark is 'unselected' and has a confidence of 0.983
# ...Selection mark is 'unselected' and has a confidence of 0.992
# ...Selection mark is 'unselected' and has a confidence of 0.992
# ...Selection mark is 'unselected' and has a confidence of 0.993
# ...Selection mark is 'unselected' and has a confidence of 0.982
# ...Selection mark is 'unselected' and has a confidence of 0.995
# ...Selection mark is 'selected' and has a confidence of 0.993
#
# Lines found on page 2
# ...Line 'MICROSOFT CORPORATION'
# ...Line 'FORM 10-Q'
# ...Line 'For the Quarter Ended March 31, 2020'
# ...Line 'INDEX'
# ...Line 'PART I.'
# ...Line 'FINANCIAL INFORMATION'
# ...Line 'Page'
# ...Line 'Item 1.'
# ...Line 'Financial Statements'
# ...Line 'a) Income Statements for the Three and Nine Months Ended March 31, 2020 and 2019'
# ...Line '3'
# ...Line 'b) Comprehensive Income Statements for the Three and Nine Months Ended March 31, 2020 and 2019'
# ...Line '4'
# ...Line 'c) Balance Sheets as of March 31, 2020 and June 30, 2019'
# ...Line '5'
# ...Line 'e) Stockholders' Equity Statements for the Three and Nine Months Ended March 31, 2020 and 2019'
# ...Line 'f)'
# ...Line 'Notes to Financial Statements'
# ...Line '8'
# ...Line 'g) Report of Independent Registered Public Accounting Firm'
# ...Line '30'
# ...Line '6'
# ...Line 'd) Cash Flows Statements for the Three and Nine Months Ended March 31, 2020 and 2019'
# ...Line '7'
# ...Line 'Item 2.'
# ...Line 'Management's Discussion and Analysis of Financial Condition and Results of Operations'
# ...Line '31'
# ...Line 'Item 3.'
# ...Line 'Quantitative and Qualitative Disclosures About Market Risk'
# ...Line '47'
# ...Line 'Item 4.'
# ...Line 'Controls and Procedures'
# ...Line '47'
# ...Line 'PART II. OTHER INFORMATION'
# ...Line 'Item 1.'
# ...Line 'Legal Proceedings'
# ...Line '48'
# ...Line 'Item 1A.'
# ...Line 'Risk Factors'
# ...Line 'Item 2.'
# ...Line 'Unregistered Sales of Equity Securities and Use of Proceeds'
# ...Line '61'
# ...Line 'Item 6.'
# ...Line 'Exhibits'
# ...Line '62'
# ...Line '63'
# ...Line '48'
# ...Line 'SIGNATURE'
# ...Line '2'
# ...Word 'MICROSOFT' has a confidence of 0.992
# ...Word 'CORPORATION' has a confidence of 0.993
# ...Word 'FORM' has a confidence of 0.993
# ...Word '10-Q' has a confidence of 0.993
# ...Word 'For' has a confidence of 0.997
# ...Word 'the' has a confidence of 0.997
# ...Word 'Quarter' has a confidence of 0.994
# ...Word 'Ended' has a confidence of 0.995
# ...Word 'March' has a confidence of 0.995
# ...Word '31,' has a confidence of 0.963
# ...Word '2020' has a confidence of 0.992
# ...Word 'INDEX' has a confidence of 0.995
# ...Word 'PART' has a confidence of 0.991
# ...Word 'I.' has a confidence of 0.972
# ...Word 'FINANCIAL' has a confidence of 0.99
# ...Word 'INFORMATION' has a confidence of 0.992
# ...Word 'Page' has a confidence of 0.991
# ...Word 'Item' has a confidence of 0.915
# ...Word '1.' has a confidence of 0.991
# ...Word 'Financial' has a confidence of 0.99
# ...Word 'Statements' has a confidence of 0.992
# ...Word 'a)' has a confidence of 0.994
# ...Word 'Income' has a confidence of 0.993
# ...Word 'Statements' has a confidence of 0.992
# ...Word 'for' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.995
# ...Word 'Three' has a confidence of 0.995
# ...Word 'and' has a confidence of 0.995
# ...Word 'Nine' has a confidence of 0.992
# ...Word 'Months' has a confidence of 0.993
# ...Word 'Ended' has a confidence of 0.995
# ...Word 'March' has a confidence of 0.995
# ...Word '31,' has a confidence of 0.995
# ...Word '2020' has a confidence of 0.992
# ...Word 'and' has a confidence of 0.994
# ...Word '2019' has a confidence of 0.987
# ...Word '3' has a confidence of 0.997
# ...Word 'b)' has a confidence of 0.995
# ...Word 'Comprehensive' has a confidence of 0.972
# ...Word 'Income' has a confidence of 0.985
# ...Word 'Statements' has a confidence of 0.983
# ...Word 'for' has a confidence of 0.995
# ...Word 'the' has a confidence of 0.996
# ...Word 'Three' has a confidence of 0.991
# ...Word 'and' has a confidence of 0.996
# ...Word 'Nine' has a confidence of 0.992
# ...Word 'Months' has a confidence of 0.995
# ...Word 'Ended' has a confidence of 0.995
# ...Word 'March' has a confidence of 0.989
# ...Word '31,' has a confidence of 0.92
# ...Word '2020' has a confidence of 0.991
# ...Word 'and' has a confidence of 0.996
# ...Word '2019' has a confidence of 0.992
# ...Word '4' has a confidence of 0.997
# ...Word 'c)' has a confidence of 0.995
# ...Word 'Balance' has a confidence of 0.993
# ...Word 'Sheets' has a confidence of 0.994
# ...Word 'as' has a confidence of 0.996
# ...Word 'of' has a confidence of 0.996
# ...Word 'March' has a confidence of 0.995
# ...Word '31,' has a confidence of 0.988
# ...Word '2020' has a confidence of 0.992
# ...Word 'and' has a confidence of 0.961
# ...Word 'June' has a confidence of 0.993
# ...Word '30,' has a confidence of 0.995
# ...Word '2019' has a confidence of 0.983
# ...Word '5' has a confidence of 0.995
# ...Word 'e)' has a confidence of 0.995
# ...Word 'Stockholders'' has a confidence of 0.974
# ...Word 'Equity' has a confidence of 0.977
# ...Word 'Statements' has a confidence of 0.992
# ...Word 'for' has a confidence of 0.996
# ...Word 'the' has a confidence of 0.996
# ...Word 'Three' has a confidence of 0.995
# ...Word 'and' has a confidence of 0.995
# ...Word 'Nine' has a confidence of 0.993
# ...Word 'Months' has a confidence of 0.995
# ...Word 'Ended' has a confidence of 0.993
# ...Word 'March' has a confidence of 0.995
# ...Word '31,' has a confidence of 0.995
# ...Word '2020' has a confidence of 0.992
# ...Word 'and' has a confidence of 0.997
# ...Word '2019' has a confidence of 0.992
# ...Word 'f)' has a confidence of 0.918
# ...Word 'Notes' has a confidence of 0.994
# ...Word 'to' has a confidence of 0.996
# ...Word 'Financial' has a confidence of 0.993
# ...Word 'Statements' has a confidence of 0.993
# ...Word '8' has a confidence of 0.995
# ...Word 'g)' has a confidence of 0.993
# ...Word 'Report' has a confidence of 0.995
# ...Word 'of' has a confidence of 0.992
# ...Word 'Independent' has a confidence of 0.97
# ...Word 'Registered' has a confidence of 0.992
# ...Word 'Public' has a confidence of 0.936
# ...Word 'Accounting' has a confidence of 0.992
# ...Word 'Firm' has a confidence of 0.992
# ...Word '30' has a confidence of 0.998
# ...Word '6' has a confidence of 0.995
# ...Word 'd)' has a confidence of 0.993
# ...Word 'Cash' has a confidence of 0.993
# ...Word 'Flows' has a confidence of 0.992
# ...Word 'Statements' has a confidence of 0.99
# ...Word 'for' has a confidence of 0.947
# ...Word 'the' has a confidence of 0.995
# ...Word 'Three' has a confidence of 0.995
# ...Word 'and' has a confidence of 0.995
# ...Word 'Nine' has a confidence of 0.99
# ...Word 'Months' has a confidence of 0.993
# ...Word 'Ended' has a confidence of 0.995
# ...Word 'March' has a confidence of 0.995
# ...Word '31,' has a confidence of 0.961
# ...Word '2020' has a confidence of 0.991
# ...Word 'and' has a confidence of 0.996
# ...Word '2019' has a confidence of 0.983
# ...Word '7' has a confidence of 0.995
# ...Word 'Item' has a confidence of 0.915
# ...Word '2.' has a confidence of 0.995
# ...Word 'Management's' has a confidence of 0.993
# ...Word 'Discussion' has a confidence of 0.993
# ...Word 'and' has a confidence of 0.992
# ...Word 'Analysis' has a confidence of 0.968
# ...Word 'of' has a confidence of 0.995
# ...Word 'Financial' has a confidence of 0.993
# ...Word 'Condition' has a confidence of 0.991
# ...Word 'and' has a confidence of 0.994
# ...Word 'Results' has a confidence of 0.993
# ...Word 'of' has a confidence of 0.994
# ...Word 'Operations' has a confidence of 0.993
# ...Word '31' has a confidence of 0.995
# ...Word 'Item' has a confidence of 0.93
# ...Word '3.' has a confidence of 0.995
# ...Word 'Quantitative' has a confidence of 0.993
# ...Word 'and' has a confidence of 0.993
# ...Word 'Qualitative' has a confidence of 0.993
# ...Word 'Disclosures' has a confidence of 0.993
# ...Word 'About' has a confidence of 0.993
# ...Word 'Market' has a confidence of 0.994
# ...Word 'Risk' has a confidence of 0.992
# ...Word '47' has a confidence of 0.997
# ...Word 'Item' has a confidence of 0.928
# ...Word '4.' has a confidence of 0.992
# ...Word 'Controls' has a confidence of 0.993
# ...Word 'and' has a confidence of 0.996
# ...Word 'Procedures' has a confidence of 0.993
# ...Word '47' has a confidence of 0.997
# ...Word 'PART' has a confidence of 0.993
# ...Word 'II.' has a confidence of 0.973
# ...Word 'OTHER' has a confidence of 0.995
# ...Word 'INFORMATION' has a confidence of 0.993
# ...Word 'Item' has a confidence of 0.916
# ...Word '1.' has a confidence of 0.995
# ...Word 'Legal' has a confidence of 0.995
# ...Word 'Proceedings' has a confidence of 0.993
# ...Word '48' has a confidence of 0.992
# ...Word 'Item' has a confidence of 0.932
# ...Word '1A.' has a confidence of 0.993
# ...Word 'Risk' has a confidence of 0.992
# ...Word 'Factors' has a confidence of 0.994
# ...Word 'Item' has a confidence of 0.916
# ...Word '2.' has a confidence of 0.995
# ...Word 'Unregistered' has a confidence of 0.991
# ...Word 'Sales' has a confidence of 0.995
# ...Word 'of' has a confidence of 0.996
# ...Word 'Equity' has a confidence of 0.965
# ...Word 'Securities' has a confidence of 0.989
# ...Word 'and' has a confidence of 0.996
# ...Word 'Use' has a confidence of 0.995
# ...Word 'of' has a confidence of 0.995
# ...Word 'Proceeds' has a confidence of 0.994
# ...Word '61' has a confidence of 0.996
# ...Word 'Item' has a confidence of 0.924
# ...Word '6.' has a confidence of 0.995
# ...Word 'Exhibits' has a confidence of 0.995
# ...Word '62' has a confidence of 0.996
# ...Word '63' has a confidence of 0.996
# ...Word '48' has a confidence of 0.997
# ...Word 'SIGNATURE' has a confidence of 0.994
# ...Word '2' has a confidence of 0.997
#
# Lines found on page 3
# ...Line 'PART I'
# ...Line 'Item 1'
# ...Line 'PART I. FINANCIAL INFORMATION'
# ...Line 'ITEM 1. FINANCIAL STATEMENTS'
# ...Line 'INCOME STATEMENTS'
# ...Line '(In millions, except per share amounts) (Unaudited)'
# ...Line 'Three Months Ended'
# ...Line 'March 31,'
# ...Line 'Nine Months Ended'
# ...Line 'March 31,'
# ...Line '2020'
# ...Line '2019'
# ...Line '2020'
# ...Line '2019'
# ...Line 'Revenue:'
# ...Line 'Product'
# ...Line '$'
# ...Line '15,871'
# ...Line '$'
# ...Line '15,448'
# ...Line '$'
# ...Line '49,894'
# ...Line '$'
# ...Line '48,966'
# ...Line 'Service and other'
# ...Line '19,150'
# ...Line '15,123'
# ...Line '55,088'
# ...Line '43,160'
# ...Line 'Total revenue'
# ...Line '35,021'
# ...Line '30,571'
# ...Line '104,982'
# ...Line '92,126'
# ...Line 'Cost of revenue:'
# ...Line 'Product'
# ...Line '3,376'
# ...Line '3,441'
# ...Line '11,647'
# ...Line '12,975'
# ...Line 'Service and other'
# ...Line '7,599'
# ...Line '6,729'
# ...Line '22,092'
# ...Line '19,523'
# ...Line 'Total cost of revenue'
# ...Line '10,975'
# ...Line '10,170'
# ...Line '33,739'
# ...Line '32,498'
# ...Line 'Gross margin'
# ...Line '24,046'
# ...Line '20,401'
# ...Line '4,316'
# ...Line '71,243'
# ...Line '59,628'
# ...Line 'Research and development'
# ...Line '4,887'
# ...Line '14,055'
# ...Line '12,363'
# ...Line 'Sales and marketing'
# ...Line '4,911'
# ...Line '4,565'
# ...Line '14,181'
# ...Line '13,251'
# ...Line 'General and administrative'
# ...Line '1,273'
# ...Line '1,179'
# ...Line '3,455'
# ...Line '3,460'
# ...Line 'Operating income'
# ...Line '12,975'
# ...Line '10,341'
# ...Line '39,552'
# ...Line '30,554'
# ...Line 'Other income (expense), net'
# ...Line '(132)'
# ...Line '145'
# ...Line '62'
# ...Line '538'
# ...Line 'Income before income taxes'
# ...Line '12,843'
# ...Line '10,486'
# ...Line '39,614'
# ...Line '31,092'
# ...Line 'Provision for income taxes'
# ...Line '2,091'
# ...Line '1,677'
# ...Line '6,535'
# ...Line '5,039'
# ...Line 'Net income'
# ...Line '$'
# ...Line '10,752'
# ...Line '$'
# ...Line '8,809'
# ...Line '$'
# ...Line '33,079'
# ...Line '$'
# ...Line '26,053'
# ...Line 'Earnings per share:'
# ...Line '1.15'
# ...Line 'Basic'
# ...Line '$'
# ...Line '1.41'
# ...Line '$'
# ...Line '$'
# ...Line '4.34'
# ...Line '$'
# ...Line '3.39'
# ...Line 'Diluted'
# ...Line '$'
# ...Line '1.40'
# ...Line '$'
# ...Line '1.14'
# ...Line '$'
# ...Line '4.30'
# ...Line '$'
# ...Line '3.36'
# ...Line 'Weighted average shares outstanding:'
# ...Line 'Basic'
# ...Line '7,602'
# ...Line '7,672'
# ...Line '7,619'
# ...Line '7,679'
# ...Line 'Diluted'
# ...Line '7,675'
# ...Line '7,744'
# ...Line '7,693'
# ...Line '7,759'
# ...Line 'Refer to accompanying notes.'
# ...Line '3'
# ...Word 'PART' has a confidence of 0.992
# ...Word 'I' has a confidence of 0.74
# ...Word 'Item' has a confidence of 0.931
# ...Word '1' has a confidence of 0.961
# ...Word 'PART' has a confidence of 0.992
# ...Word 'I.' has a confidence of 0.961
# ...Word 'FINANCIAL' has a confidence of 0.993
# ...Word 'INFORMATION' has a confidence of 0.992
# ...Word 'ITEM' has a confidence of 0.992
# ...Word '1.' has a confidence of 0.995
# ...Word 'FINANCIAL' has a confidence of 0.993
# ...Word 'STATEMENTS' has a confidence of 0.993
# ...Word 'INCOME' has a confidence of 0.995
# ...Word 'STATEMENTS' has a confidence of 0.993
# ...Word '(In' has a confidence of 0.992
# ...Word 'millions,' has a confidence of 0.973
# ...Word 'except' has a confidence of 0.991
# ...Word 'per' has a confidence of 0.996
# ...Word 'share' has a confidence of 0.995
# ...Word 'amounts)' has a confidence of 0.993
# ...Word '(Unaudited)' has a confidence of 0.983
# ...Word 'Three' has a confidence of 0.995
# ...Word 'Months' has a confidence of 0.995
# ...Word 'Ended' has a confidence of 0.995
# ...Word 'March' has a confidence of 0.995
# ...Word '31,' has a confidence of 0.994
# ...Word 'Nine' has a confidence of 0.993
# ...Word 'Months' has a confidence of 0.995
# ...Word 'Ended' has a confidence of 0.995
# ...Word 'March' has a confidence of 0.995
# ...Word '31,' has a confidence of 0.995
# ...Word '2020' has a confidence of 0.993
# ...Word '2019' has a confidence of 0.992
# ...Word '2020' has a confidence of 0.993
# ...Word '2019' has a confidence of 0.993
# ...Word 'Revenue:' has a confidence of 0.994
# ...Word 'Product' has a confidence of 0.994
# ...Word '$' has a confidence of 0.967
# ...Word '15,871' has a confidence of 0.995
# ...Word '$' has a confidence of 0.932
# ...Word '15,448' has a confidence of 0.995
# ...Word '$' has a confidence of 0.95
# ...Word '49,894' has a confidence of 0.993
# ...Word '$' has a confidence of 0.972
# ...Word '48,966' has a confidence of 0.995
# ...Word 'Service' has a confidence of 0.995
# ...Word 'and' has a confidence of 0.995
# ...Word 'other' has a confidence of 0.995
# ...Word '19,150' has a confidence of 0.994
# ...Word '15,123' has a confidence of 0.993
# ...Word '55,088' has a confidence of 0.995
# ...Word '43,160' has a confidence of 0.995
# ...Word 'Total' has a confidence of 0.995
# ...Word 'revenue' has a confidence of 0.994
# ...Word '35,021' has a confidence of 0.995
# ...Word '30,571' has a confidence of 0.995
# ...Word '104,982' has a confidence of 0.995
# ...Word '92,126' has a confidence of 0.995
# ...Word 'Cost' has a confidence of 0.993
# ...Word 'of' has a confidence of 0.996
# ...Word 'revenue:' has a confidence of 0.984
# ...Word 'Product' has a confidence of 0.995
# ...Word '3,376' has a confidence of 0.994
# ...Word '3,441' has a confidence of 0.994
# ...Word '11,647' has a confidence of 0.995
# ...Word '12,975' has a confidence of 0.995
# ...Word 'Service' has a confidence of 0.995
# ...Word 'and' has a confidence of 0.993
# ...Word 'other' has a confidence of 0.995
# ...Word '7,599' has a confidence of 0.984
# ...Word '6,729' has a confidence of 0.994
# ...Word '22,092' has a confidence of 0.995
# ...Word '19,523' has a confidence of 0.995
# ...Word 'Total' has a confidence of 0.994
# ...Word 'cost' has a confidence of 0.993
# ...Word 'of' has a confidence of 0.996
# ...Word 'revenue' has a confidence of 0.995
# ...Word '10,975' has a confidence of 0.995
# ...Word '10,170' has a confidence of 0.995
# ...Word '33,739' has a confidence of 0.995
# ...Word '32,498' has a confidence of 0.995
# ...Word 'Gross' has a confidence of 0.995
# ...Word 'margin' has a confidence of 0.994
# ...Word '24,046' has a confidence of 0.995
# ...Word '20,401' has a confidence of 0.995
# ...Word '4,316' has a confidence of 0.994
# ...Word '71,243' has a confidence of 0.994
# ...Word '59,628' has a confidence of 0.995
# ...Word 'Research' has a confidence of 0.995
# ...Word 'and' has a confidence of 0.996
# ...Word 'development' has a confidence of 0.983
# ...Word '4,887' has a confidence of 0.995
# ...Word '14,055' has a confidence of 0.995
# ...Word '12,363' has a confidence of 0.995
# ...Word 'Sales' has a confidence of 0.995
# ...Word 'and' has a confidence of 0.996
# ...Word 'marketing' has a confidence of 0.994
# ...Word '4,911' has a confidence of 0.993
# ...Word '4,565' has a confidence of 0.995
# ...Word '14,181' has a confidence of 0.995
# ...Word '13,251' has a confidence of 0.994
# ...Word 'General' has a confidence of 0.994
# ...Word 'and' has a confidence of 0.997
# ...Word 'administrative' has a confidence of 0.981
# ...Word '1,273' has a confidence of 0.993
# ...Word '1,179' has a confidence of 0.995
# ...Word '3,455' has a confidence of 0.994
# ...Word '3,460' has a confidence of 0.995
# ...Word 'Operating' has a confidence of 0.982
# ...Word 'income' has a confidence of 0.951
# ...Word '12,975' has a confidence of 0.994
# ...Word '10,341' has a confidence of 0.995
# ...Word '39,552' has a confidence of 0.995
# ...Word '30,554' has a confidence of 0.993
# ...Word 'Other' has a confidence of 0.995
# ...Word 'income' has a confidence of 0.995
# ...Word '(expense),' has a confidence of 0.973
# ...Word 'net' has a confidence of 0.997
# ...Word '(132)' has a confidence of 0.995
# ...Word '145' has a confidence of 0.993
# ...Word '62' has a confidence of 0.996
# ...Word '538' has a confidence of 0.996
# ...Word 'Income' has a confidence of 0.951
# ...Word 'before' has a confidence of 0.995
# ...Word 'income' has a confidence of 0.995
# ...Word 'taxes' has a confidence of 0.995
# ...Word '12,843' has a confidence of 0.995
# ...Word '10,486' has a confidence of 0.995
# ...Word '39,614' has a confidence of 0.995
# ...Word '31,092' has a confidence of 0.995
# ...Word 'Provision' has a confidence of 0.985
# ...Word 'for' has a confidence of 0.995
# ...Word 'income' has a confidence of 0.993
# ...Word 'taxes' has a confidence of 0.995
# ...Word '2,091' has a confidence of 0.995
# ...Word '1,677' has a confidence of 0.994
# ...Word '6,535' has a confidence of 0.994
# ...Word '5,039' has a confidence of 0.995
# ...Word 'Net' has a confidence of 0.992
# ...Word 'income' has a confidence of 0.995
# ...Word '$' has a confidence of 0.961
# ...Word '10,752' has a confidence of 0.995
# ...Word '$' has a confidence of 0.971
# ...Word '8,809' has a confidence of 0.995
# ...Word '$' has a confidence of 0.979
# ...Word '33,079' has a confidence of 0.994
# ...Word '$' has a confidence of 0.972
# ...Word '26,053' has a confidence of 0.995
# ...Word 'Earnings' has a confidence of 0.992
# ...Word 'per' has a confidence of 0.996
# ...Word 'share:' has a confidence of 0.993
# ...Word '1.15' has a confidence of 0.992
# ...Word 'Basic' has a confidence of 0.995
# ...Word '$' has a confidence of 0.961
# ...Word '1.41' has a confidence of 0.992
# ...Word '$' has a confidence of 0.948
# ...Word '$' has a confidence of 0.986
# ...Word '4.34' has a confidence of 0.993
# ...Word '$' has a confidence of 0.967
# ...Word '3.39' has a confidence of 0.993
# ...Word 'Diluted' has a confidence of 0.995
# ...Word '$' has a confidence of 0.966
# ...Word '1.40' has a confidence of 0.993
# ...Word '$' has a confidence of 0.982
# ...Word '1.14' has a confidence of 0.992
# ...Word '$' has a confidence of 0.993
# ...Word '4.30' has a confidence of 0.993
# ...Word '$' has a confidence of 0.972
# ...Word '3.36' has a confidence of 0.993
# ...Word 'Weighted' has a confidence of 0.994
# ...Word 'average' has a confidence of 0.995
# ...Word 'shares' has a confidence of 0.995
# ...Word 'outstanding:' has a confidence of 0.993
# ...Word 'Basic' has a confidence of 0.995
# ...Word '7,602' has a confidence of 0.995
# ...Word '7,672' has a confidence of 0.995
# ...Word '7,619' has a confidence of 0.995
# ...Word '7,679' has a confidence of 0.992
# ...Word 'Diluted' has a confidence of 0.993
# ...Word '7,675' has a confidence of 0.995
# ...Word '7,744' has a confidence of 0.995
# ...Word '7,693' has a confidence of 0.992
# ...Word '7,759' has a confidence of 0.995
# ...Word 'Refer' has a confidence of 0.995
# ...Word 'to' has a confidence of 0.992
# ...Word 'accompanying' has a confidence of 0.993
# ...Word 'notes.' has a confidence of 0.992
# ...Word '3' has a confidence of 0.997
#
# Lines found on page 4
# ...Line 'PART I'
# ...Line 'Item 1'
# ...Line 'COMPREHENSIVE INCOME STATEMENTS'
# ...Line '(In millions) (Unaudited)'
# ...Line 'Three Months Ended'
# ...Line 'March 31,'
# ...Line 'Nine Months Ended'
# ...Line 'March 31,'
# ...Line '2020'
# ...Line '2019'
# ...Line '2020'
# ...Line '2019'
# ...Line 'Net income'
# ...Line '$'
# ...Line '10,752'
# ...Line '$'
# ...Line '8,809'
# ...Line '$'
# ...Line '33,079'
# ...Line '$'
# ...Line '26,053'
# ...Line 'Other comprehensive income (loss), net of tax:'
# ...Line 'Net change related to derivatives'
# ...Line '(36)'
# ...Line '(33)'
# ...Line '(42)'
# ...Line '(93)'
# ...Line 'Net change related to investments'
# ...Line '3,508'
# ...Line '714'
# ...Line '3,665'
# ...Line '1,334'
# ...Line 'Translation adjustments and other'
# ...Line '(541)'
# ...Line '67'
# ...Line '(607)'
# ...Line '(252'
# ...Line 'Other comprehensive income'
# ...Line '2,931'
# ...Line '748'
# ...Line '3,016'
# ...Line '989'
# ...Line 'Comprehensive income'
# ...Line '$'
# ...Line '13,683'
# ...Line '$'
# ...Line '9,557'
# ...Line '$'
# ...
# ...Cell[7][0] has text 'Other comprehensive income'
# ...Cell[7][1] has text '2,931'
# ...Cell[7][2] has text '748'
# ...Cell[7][3] has text '3,016'
# ...Cell[7][4] has text '989'
# ...Cell[8][0] has text 'Comprehensive income'
# ...Cell[8][1] has text '$ 13,683'
# ...Cell[8][2] has text '$ 9,557'
# ...Cell[8][3] has text '$ 36,095'
# ...Cell[8][4] has text '$ 27,042'
#
# Table 5 can be found on page:
# ...5
# ...Cell[0][0] has text ''
# ...Cell[0][1] has text 'March 31, June 30, 2020 2019'
# ...Cell[1][0] has text 'Assets'
# ...Cell[1][1] has text ''
# ...Cell[1][2] has text ''
# ...Cell[2][0] has text 'Current assets:'
# ...Cell[2][1] has text ''
# ...Cell[2][2] has text ''
# ...Cell[3][0] has text 'Cash and cash equivalents'
# ...Cell[3][1] has text '$ 11,710'
# ...Cell[3][2] has text '$ 11,356'
# ...Cell[4][0] has text 'Short-term investments'
# ...Cell[4][1] has text '125,916'
# ...Cell[4][2] has text '122,463'
# ...Cell[5][0] has text 'Total cash, cash equivalents, and short-term investments'
# ...Cell[5][1] has text '137,626'
# ...Cell[5][2] has text '133,819'
# ...Cell[6][0] has text 'Accounts receivable, net of allowance for doubtful accounts of $446 and $411'
# ...Cell[6][1] has text '22,699'
# ...Cell[6][2] has text '29,524'
# ...Cell[7][0] has text 'Inventories'
# ...Cell[7][1] has text '1,644'
# ...Cell[7][2] has text '2,063'
# ...Cell[8][0] has text 'Other current assets'
# ...Cell[8][1] has text '8,536'
# ...Cell[8][2] has text '10,146'
# ...Cell[9][0] has text 'Total current assets'
# ...Cell[9][1] has text '170,505'
# ...Cell[9][2] has text '175,552'
# ...Cell[10][0] has text 'Property and equipment, net of accumulated depreciation of $41,512 and $35,330'
# ...Cell[10][1] has text '41,221'
# ...Cell[10][2] has text '36,477'
# ...Cell[11][0] has text 'Operating lease right-of-use assets'
# ...Cell[11][1] has text '8,448'
# ...Cell[11][2] has text '7,379'
# ...Cell[12][0] has text 'Equity investments'
# ...Cell[12][1] has text '2,660'
# ...Cell[12][2] has text '2,649'
# ...Cell[13][0] has text 'Goodwill'
# ...Cell[13][1] has text '42,064'
# ...Cell[13][2] has text '42,026'
# ...Cell[14][0] has text 'Intangible assets, net'
# ...Cell[14][1] has text '6,855'
# ...Cell[14][2] has text '7,750'
# ...Cell[15][0] has text 'Other long-term assets'
# ...Cell[15][1] has text '13,696'
# ...Cell[15][2] has text '14,723'
# ...Cell[16][0] has text 'Total assets'
# ...Cell[16][1] has text '$ 285,449'
# ...Cell[16][2] has text '$ 286,556'
# ...Cell[17][0] has text 'Liabilities and stockholders' equity'
# ...Cell[17][1] has text ''
# ...Cell[17][2] has text ''
# ...Cell[18][0] has text 'Current liabilities:'
# ...Cell[18][1] has text ''
# ...Cell[18][2] has text ''
# ...Cell[19][0] has text 'Accounts payable'
# ...Cell[19][1] has text '$ 9,246'
# ...Cell[19][2] has text '$ 9,382'
# ...Cell[20][0] has text 'Current portion of long-term debt'
# ...Cell[20][1] has text '3,748'
# ...Cell[20][2] has text '5,516'
# ...Cell[21][0] has text 'Accrued compensation'
# ...Cell[21][1] has text '6,254'
# ...Cell[21][2] has text '6,830'
# ...Cell[22][0] has text 'Short-term income taxes'
# ...Cell[22][1] has text '3,296'
# ...Cell[22][2] has text '5,665'
# ...Cell[23][0] has text 'Short-term unearned revenue'
# ...Cell[23][1] has text '27,012'
# ...Cell[23][2] has text '32,676'
# ...Cell[24][0] has text 'Other current liabilities'
# ...Cell[24][1] has text '9,151'
# ...Cell[24][2] has text '9,351'
# ...Cell[25][0] has text 'Total current liabilities'
# ...Cell[25][1] has text '58,707'
# ...Cell[25][2] has text '69,420'
# ...Cell[26][0] has text 'Long-term debt'
# ...Cell[26][1] has text '62,862'
# ...Cell[26][2] has text '66,662'
# ...Cell[27][0] has text 'Long-term income taxes'
# ...Cell[27][1] has text '28,888'
# ...Cell[27][2] has text '29,612'
# ...Cell[28][0] has text 'Long-term unearned revenue'
# ...Cell[28][1] has text '3,385'
# ...Cell[28][2] has text '4,530'
# ...Cell[29][0] has text 'Deferred income taxes'
# ...Cell[29][1] has text '185'
# ...Cell[29][2] has text '233'
# ...Cell[30][0] has text 'Operating lease liabilities'
# ...Cell[30][1] has text '7,248'
# ...Cell[30][2] has text '6,188'
# ...Cell[31][0] has text 'Other long-term liabilities'
# ...Cell[31][1] has text '9,673'
# ...Cell[31][2] has text '7,581'
# ...Cell[32][0] has text 'Total liabilities'
# ...Cell[32][1] has text '170,948'
# ...Cell[32][2] has text '184,226'
# ...Cell[33][0] has text 'Commitments and contingencies'
# ...Cell[33][1] has text ''
# ...Cell[33][2] has text ''
# ...Cell[34][0] has text 'Stockholders' equity:'
# ...Cell[34][1] has text ''
# ...Cell[34][2] has text ''
# ...Cell[35][0] has text 'Common stock and paid-in capital - shares authorized 24,000; outstanding 7,590 and 7,643'
# ...Cell[35][1] has text '79,813'
# ...Cell[35][2] has text '78,520'
# ...Cell[36][0] has text 'Retained earnings'
# ...Cell[36][1] has text '32,012'
# ...Cell[36][2] has text '24,150'
# ...Cell[37][0] has text 'Accumulated other comprehensive income (loss)'
# ...Cell[37][1] has text '2,676'
# ...Cell[37][2] has text '(340)'
# ...Cell[38][0] has text 'Total stockholders' equity'
# ...Cell[38][1] has text '114,501'
# ...Cell[38][2] has text '102,330'
# ...Cell[39][0] has text 'Total liabilities and stockholders' equity'
# ...Cell[39][1] has text '$ 285,449'
# ...Cell[39][2] has text '$ 286,556'
#
# Table 6 can be found on page:
# ...6
# ...Cell[0][0] has text '(In millions) (Unaudited)'
# ...Cell[0][1] has text 'Three Months Ended Nine Months Ended March 31, March 31,'
# ...Cell[1][0] has text ''
# ...Cell[1][1] has text '2020'
# ...Cell[1][2] has text '2019'
# ...Cell[1][3] has text '2020'
# ...Cell[1][4] has text '2019'
# ...Cell[2][0] has text 'Operations'
# ...Cell[2][1] has text ''
# ...Cell[2][2] has text ''
# ...Cell[2][3] has text ''
# ...Cell[2][4] has text ''
# ...Cell[3][0] has text 'Net income'
# ...Cell[3][1] has text '10,752
# $'
# ...Cell[3][2] has text '$ 8,809'
# ...Cell[3][3] has text '$ 33,079'
# ...Cell[3][4] has text '$ 26,053'
# ...Cell[4][0] has text 'Adjustments to reconcile net income to net cash from operations:'
# ...Cell[4][1] has text ''
# ...Cell[4][2] has text ''
# ...Cell[4][3] has text ''
# ...Cell[4][4] has text ''
# ...Cell[5][0] has text 'Depreciation, amortization, and other'
# ...Cell[5][1] has text '3,118'
# ...Cell[5][2] has text '2,926'
# ...Cell[5][3] has text '9,292'
# ...Cell[5][4] has text '8,758'
# ...Cell[6][0] has text 'Stock-based compensation expense'
# ...Cell[6][1] has text '1,338'
# ...Cell[6][2] has text '1,172'
# ...Cell[6][3] has text '3,940'
# ...Cell[6][4] has text '3,462'
# ...Cell[7][0] has text 'Net recognized losses (gains) on investments and derivatives'
# ...Cell[7][1] has text '52'
# ...Cell[7][2] has text '(95)'
# ...Cell[7][3] has text '(140)'
# ...Cell[7][4] has text '(470)'
# ...Cell[8][0] has text 'Deferred income taxes'
# ...Cell[8][1] has text '(206)'
# ...Cell[8][2] has text '(320)'
# ...Cell[8][3] has text '(436)'
# ...Cell[8][4] has text '(740)'
# ...Cell[9][0] has text 'Changes in operating assets and liabilities:'
# ...Cell[9][1] has text ''
# ...Cell[9][2] has text ''
# ...Cell[9][3] has text ''
# ...Cell[9][4] has text ''
# ...Cell[10][0] has text 'Accounts receivable'
# ...Cell[10][1] has text '891'
# ...Cell[10][2] has text '460'
# ...Cell[10][3] has text '6,778'
# ...Cell[10][4] has text '7,258'
# ...Cell[11][0] has text 'Inventories'
# ...Cell[11][1] has text '181'
# ...Cell[11][2] has text '12'
# ...Cell[11][3] has text '419'
# ...Cell[11][4] has text '710'
# ...Cell[12][0] has text 'Other current assets'
# ...Cell[12][1] has text '94'
# ...Cell[12][2] has text '(14)'
# ...Cell[12][3] has text '(179)'
# ...Cell[12][4] has text '(864)'
# ...Cell[13][0] has text 'Other long-term assets'
# ...Cell[13][1] has text '124'
# ...Cell[13][2] has text '(517)'
# ...Cell[13][3] has text '(726)'
# ...Cell[13][4] has text '(969'
# ...Cell[14][0] has text 'Accounts payable'
# ...Cell[14][1] has text '546'
# ...Cell[14][2] has text '(197)'
# ...Cell[14][3] has text '(8)'
# ...Cell[14][4] has text '(1,032)'
# ...Cell[15][0] has text 'Unearned revenue'
# ...Cell[15][1] has text '(736)'
# ...Cell[15][2] has text '20'
# ...Cell[15][3] has text '(6,564)'
# ...Cell[15][4] has text '(4,543)'
# ...Cell[16][0] has text 'Income taxes'
# ...Cell[16][1] has text '765'
# ...Cell[16][2] has text '276'
# ...Cell[16][3] has text '(3,042)'
# ...Cell[16][4] has text '(879)'
# ...Cell[17][0] has text 'Other current liabilities'
# ...Cell[17][1] has text '695'
# ...Cell[17][2] has text '649'
# ...Cell[17][3] has text '(1,136)'
# ...Cell[17][4] has text '(1,017)'
# ...Cell[18][0] has text 'Other long-term liabilities'
# ...Cell[18][1] has text '(110)'
# ...Cell[18][2] has text '339'
# ...Cell[18][3] has text '725'
# ...Cell[18][4] has text '350'
# ...Cell[19][0] has text 'Net cash from operations'
# ...Cell[19][1] has text '17,504'
# ...Cell[19][2] has text '13,520'
# ...Cell[19][3] has text '42,002'
# ...Cell[19][4] has text '36,077'
# ...Cell[20][0] has text 'Financing'
# ...Cell[20][1] has text ''
# ...Cell[20][2] has text ''
# ...Cell[20][3] has text ''
# ...Cell[20][4] has text ''
# ...Cell[21][0] has text 'Repayments of debt'
# ...Cell[21][1] has text '(3,000)'
# ...Cell[21][2] has text '0'
# ...Cell[21][3] has text '(5,518)'
# ...Cell[21][4] has text '(3,000)'
# ...Cell[22][0] has text 'Common stock issued'
# ...Cell[22][1] has text '342'
# ...Cell[22][2] has text '274'
# ...Cell[22][3] has text '1,003'
# ...Cell[22][4] has text '834'
# ...Cell[23][0] has text 'Common stock repurchased'
# ...Cell[23][1] has text '(7,059)'
# ...Cell[23][2] has text '(4,753)'
# ...Cell[23][3] has text '(17,177)'
# ...Cell[23][4] has text '(14,910)'
# ...Cell[24][0] has text 'Common stock cash dividends paid'
# ...Cell[24][1] has text '(3,876)'
# ...Cell[24][2] has text '(3,526)'
# ...Cell[24][3] has text '(11,272)'
# ...Cell[24][4] has text '(10,290)'
# ...Cell[25][0] has text 'Other, net'
# ...Cell[25][1] has text '(1,052)'
# ...Cell[25][2] has text '404'
# ...Cell[25][3] has text '(805)'
# ...Cell[25][4] has text '(835)'
# ...Cell[26][0] has text 'Net cash used in financing'
# ...Cell[26][1] has text '(14,645)'
# ...Cell[26][2] has text '(7,601)'
# ...Cell[26][3] has text '(33,769)'
# ...Cell[26][4] has text '(28,201)'
# ...Cell[27][0] has text 'Investing'
# ...Cell[27][1] has text ''
# ...Cell[27][2] has text ''
# ...Cell[27][3] has text ''
# ...Cell[27][4] has text ''
# ...Cell[28][0] has text 'Additions to property and equipment'
# ...Cell[28][1] has text '(3,767)'
# ...Cell[28][2] has text '(2,565)'
# ...Cell[28][3] has text '(10,697)'
# ...Cell[28][4] has text '(9,874)'
# ...Cell[29][0] has text 'Acquisition of companies, net of cash acquired, and purchases of
# intangible and other assets'
# ...Cell[29][1] has text '(329)'
# ...Cell[29][2] has text '(269)'
# ...Cell[29][3] has text '(871)'
# ...Cell[29][4] has text '(2,107)'
# ...Cell[30][0] has text 'Purchases of investments'
# ...Cell[30][1] has text '(15,910)'
# ...Cell[30][2] has text '(5,846)'
# ...Cell[30][3] has text '(58,311)'
# ...Cell[30][4] has text '(42,255)'
# ...Cell[31][0] has text 'Maturities of investments'
# ...Cell[31][1] has text '17,247'
# ...Cell[31][2] has text '5,893'
# ...Cell[31][3] has text '47,559'
# ...Cell[31][4] has text '14,889'
# ...Cell[32][0] has text 'Sales of investments'
# ...Cell[32][1] has text '2,810'
# ...Cell[32][2] has text '1,424'
# ...Cell[32][3] has text '14,559'
# ...Cell[32][4] has text '30,831'
# ...Cell[33][0] has text 'Net cash from (used in) investing'
# ...Cell[33][1] has text '51'
# ...Cell[33][2] has text '(1,363)'
# ...Cell[33][3] has text '(7,761)'
# ...Cell[33][4] has text '(8,516)'
# ...Cell[34][0] has text 'Effect of foreign exchange rates on cash and cash equivalents'
# ...Cell[34][1] has text '(64)'
# ...Cell[34][2] has text '18'
# ...Cell[34][3] has text '(118)'
# ...Cell[34][4] has text '(94)'
# ...Cell[35][0] has text 'Net change in cash and cash equivalents'
# ...Cell[35][1] has text '2,846'
# ...Cell[35][2] has text '4,574'
# ...Cell[35][3] has text '354'
# ...Cell[35][4] has text '(734)'
# ...Cell[36][0] has text 'Cash and cash equivalents, beginning of period'
# ...Cell[36][1] has text '8,864'
# ...Cell[36][2] has text '6,638'
# ...Cell[36][3] has text '11,356'
# ...Cell[36][4] has text '11,946'
# ...Cell[37][0] has text 'Cash and cash equivalents, end of period'
# ...Cell[37][1] has text '$ 11,710'
# ...Cell[37][2] has text '$ 11,212'
# ...Cell[37][3] has text '$ 11,710'
# ...Cell[37][4] has text '$ 11,212'
#
# Table 7 can be found on page:
# ...7
# ...Cell[0][0] has text '(In millions) (Unaudited)'
# ...Cell[0][1] has text 'Three Months Ended Nine Months Ended March 31, March 31,'
# ...Cell[1][0] has text ''
# ...Cell[1][1] has text '2020'
# ...Cell[1][2] has text '2019'
# ...Cell[1][3] has text '2020'
# ...Cell[1][4] has text '2019'
# ...Cell[2][0] has text 'Common stock and paid-in capital'
# ...Cell[2][1] has text ''
# ...Cell[2][2] has text ''
# ...Cell[2][3] has text ''
# ...Cell[2][4] has text ''
# ...Cell[3][0] has text 'Balance, beginning of period'
# ...Cell[3][1] has text '$ 79,625'
# ...Cell[3][2] has text '$ 77,556'
# ...Cell[3][3] has text '$ 78,520'
# ...Cell[3][4] has text '$ 71,223'
# ...Cell[4][0] has text 'Common stock issued'
# ...Cell[4][1] has text '342'
# ...Cell[4][2] has text '274'
# ...Cell[4][3] has text '1,003'
# ...Cell[4][4] has text '6,521'
# ...Cell[5][0] has text 'Common stock repurchased'
# ...Cell[5][1] has text '(1,492)'
# ...Cell[5][2] has text '(1,218)'
# ...Cell[5][3] has text '(3,649)'
# ...Cell[5][4] has text '(3,433)'
# ...Cell[6][0] has text 'Stock-based compensation expense'
# ...Cell[6][1] has text '1,338'
# ...Cell[6][2] has text '1,172'
# ...Cell[6][3] has text '3,940'
# ...Cell[6][4] has text '3,462'
# ...Cell[7][0] has text 'Other, net'
# ...Cell[7][1] has text '0'
# ...Cell[7][2] has text '7'
# ...Cell[7][3] has text '(1)'
# ...Cell[7][4] has text '18'
# ...Cell[8][0] has text 'Balance, end of period'
# ...Cell[8][1] has text '79,813'
# ...Cell[8][2] has text '77,791'
# ...Cell[8][3] has text '79,813'
# ...Cell[8][4] has text '77,791'
# ...Cell[9][0] has text 'Retained earnings'
# ...Cell[9][1] has text ''
# ...Cell[9][2] has text ''
# ...Cell[9][3] has text ''
# ...Cell[9][4] has text ''
# ...Cell[10][0] has text 'Balance, beginning of period'
# ...Cell[10][1] has text '30,739'
# ...Cell[10][2] has text '16,585'
# ...Cell[10][3] has text '24,150'
# ...Cell[10][4] has text '13,682'
# ...Cell[11][0] has text 'Net income'
# ...Cell[11][1] has text '10,752'
# ...Cell[11][2] has text '8,809'
# ...Cell[11][3] has text '33,079'
# ...Cell[11][4] has text '26,053'
# ...Cell[12][0] has text 'Common stock cash dividends'
# ...Cell[12][1] has text '(3,865)'
# ...Cell[12][2] has text '(3,518)'
# ...Cell[12][3] has text '(11,627)'
# ...Cell[12][4] has text '(10,592)'
# ...Cell[13][0] has text 'Common stock repurchased'
# ...Cell[13][1] has text '(5,614)'
# ...Cell[13][2] has text '(3,538)'
# ...Cell[13][3] has text '(13,590)'
# ...Cell[13][4] has text '(11,482)'
# ...Cell[14][0] has text 'Cumulative effect of accounting changes'
# ...Cell[14][1] has text '0'
# ...Cell[14][2] has text '0'
# ...Cell[14][3] has text '0'
# ...Cell[14][4] has text '677'
# ...Cell[15][0] has text 'Balance, end of period'
# ...Cell[15][1] has text '32,012'
# ...Cell[15][2] has text '18,338'
# ...Cell[15][3] has text '32,012'
# ...Cell[15][4] has text '18,338'
# ...Cell[16][0] has text 'Accumulated other comprehensive income (loss)'
# ...Cell[16][1] has text ''
# ...Cell[16][2] has text ''
# ...Cell[16][3] has text ''
# ...Cell[16][4] has text ''
# ...Cell[17][0] has text 'Balance, beginning of period'
# ...Cell[17][1] has text '(255)'
# ...Cell[17][2] has text '(2,013)'
# ...Cell[17][3] has text '(340)'
# ...Cell[17][4] has text '(2,187)'
# ...Cell[18][0] has text 'Other comprehensive income'
# ...Cell[18][1] has text '2,931'
# ...Cell[18][2] has text '748'
# ...Cell[18][3] has text '3,016'
# ...Cell[18][4] has text '989'
# ...Cell[19][0] has text 'Cumulative effect of accounting changes'
# ...Cell[19][1] has text '0'
# ...Cell[19][2] has text '0'
# ...Cell[19][3] has text '0'
# ...Cell[19][4] has text '(67)'
# ...Cell[20][0] has text 'Balance, end of period'
# ...Cell[20][1] has text '2,676'
# ...Cell[20][2] has text '(1,265)'
# ...Cell[20][3] has text '2,676'
# ...Cell[20][4] has text '(1,265)'
# ...Cell[21][0] has text 'Total stockholders' equity'
# ...Cell[21][1] has text '$ 114,501'
# ...Cell[21][2] has text '$ 94,864'
# ...Cell[21][3] has text '$ 114,501'
# ...Cell[21][4] has text '$ 94,864'
# ...Cell[22][0] has text 'Cash dividends declared per common share'
# ...Cell[22][1] has text '$ 0.51'
# ...Cell[22][2] has text '$ 0.46'
# ...Cell[22][3] has text '$ 1.53'
# ...Cell[22][4] has text '$ 1.38'

# %% [markdown]
# ## F. Extracted document insights/ response as table of Key Value Pair using custom model

# %%
# Get the document insights as key / value table
from tabulate import tabulate

data = []

# Display key value pairs
for idx, document in enumerate(result.documents):
    print()
    print("--------Analyzing document #{}--------".format(idx + 1))
    print("Document has type {}".format(document.doc_type))
    print("Document has document type confidence {}".format(
        document.confidence))
    print("Document was analyzed with model with ID {}".format(
        result.model_id))
    print()
    for name, field in document.fields.items():
        field_value = field.value if field.value else field.content
        if field.value_type != 'list':
            data.append([name, field.value, field.confidence])

data.sort()
print(tabulate(data, headers=[
    'Label', 'Value', 'Confidence'], tablefmt='fancy_grid'))

# Display table data
for i, table in enumerate(result.tables):

    row_index = 1
    hdr = []
    rows = []
    row = []

    print("\nTable {} can be found on page:".format(i + 1))
    # for region in table.bounding_regions:
    #     print("...{}".format(i + 1, region.page_number))

    for cell in table.cells:
        if cell.row_index == 0:
            hdr.append(cell.content)
        else:
            if row_index != cell.row_index:
                rows.append(row)
                row_index = cell.row_index
                row = []

            row.append(cell.content)

    rows.append(row)
    print(tabulate(rows, headers=hdr, tablefmt='fancy_grid'))
# Out:
# --------Analyzing document #1--------
# Document has type customreceiptlrl
# Document has document type confidence 0.001
# Document was analyzed with model with ID customreceiptlrl
#
# ╒══════════════════════════╤═════════╤══════════════╕
# │ Label                    │ Value   │   Confidence │
# ╞══════════════════════════╪═════════╪══════════════╡
# │ CustomerAddress          │         │        0.79  │
# ├──────────────────────────┼─────────┼──────────────┤
# │ CustomerAddressRecipient │         │        0.792 │
# ├──────────────────────────┼─────────┼──────────────┤
# │ CustomerName             │         │        0.711 │
# ├──────────────────────────┼─────────┼──────────────┤
# │ InvoiceDate              │         │        0.247 │
# ├──────────────────────────┼─────────┼──────────────┤
# │ MerchantAddress          │         │        0.494 │
# ├──────────────────────────┼─────────┼──────────────┤
# │ MerchantName             │         │        0.423 │
# ├──────────────────────────┼─────────┼──────────────┤
# │ MerchantPhoneNumber      │         │        0.693 │
# ├──────────────────────────┼─────────┼──────────────┤
# │ ServiceEndDate           │         │        0.727 │
# ├──────────────────────────┼─────────┼──────────────┤
# │ ServiceStartDate         │         │        0.792 │
# ├──────────────────────────┼─────────┼──────────────┤
# │ Subtotal                 │         │        0.882 │
# ├──────────────────────────┼─────────┼──────────────┤
# │ Tip                      │         │        0.878 │
# ├──────────────────────────┼─────────┼──────────────┤
# │ Total                    │         │        0.127 │
# ├──────────────────────────┼─────────┼──────────────┤
# │ TotalTax                 │         │        0.792 │
# ├──────────────────────────┼─────────┼──────────────┤
# │ TransactionDate          │         │        0.48  │
# ├──────────────────────────┼─────────┼──────────────┤
# │ TransactionTime          │         │        0.727 │
# ├──────────────────────────┼─────────┼──────────────┤
# │ VendorAddress            │         │        0.762 │
# ├──────────────────────────┼─────────┼──────────────┤
# │ VendorAddressRecipient   │         │        0.791 │
# ├──────────────────────────┼─────────┼──────────────┤
# │ VendorName               │         │        0.614 │
# ╘══════════════════════════╧═════════╧══════════════╛
#
# Table 1 can be found on page:
# ╒═════════════════════════════════════════════════════════════╤═══════════════════════════════════════════════════════════════╤══════════════════════════════════════╕
# │                                                             │ Securities registered pursuant to Section 12(b) of the Act:   │                                      │
# ╞═════════════════════════════════════════════════════════════╪═══════════════════════════════════════════════════════════════╪══════════════════════════════════════╡
# │ Title of each class                                         │ Trading Symbol                                                │ Name of exchange on which registered │
# ├─────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────┼──────────────────────────────────────┤
# │ Common stock, $0.00000625 par value per share               │ MSFT                                                          │ NASDAQ                               │
# ├─────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────┼──────────────────────────────────────┤
# │ 2.125% Notes due 2021                                       │ MSFT                                                          │ NASDAQ                               │
# ├─────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────┼──────────────────────────────────────┤
# │ 3.125% Notes due 2028                                       │ MSFT                                                          │ NASDAQ                               │
# ├─────────────────────────────────────────────────────────────┼───────────────────────────────────────────────────────────────┼──────────────────────────────────────┤
# │ 2.625% Notes due 2033                                       │ MSFT                                                          │ NASDAQ                               │
# │ Securities registered pursuant to Section 12(g) of the Act: │                                                               │                                      │
# ╘═════════════════════════════════════════════════════════════╧═══════════════════════════════════════════════════════════════╧══════════════════════════════════════╛
#
# Table 2 can be found on page:
# ╒═══════════════════════════════════════════════╤════════════════════════════════════╕
# │ Class                                         │ Outstanding as of April 24, 2020   │
# ╞═══════════════════════════════════════════════╪════════════════════════════════════╡
# │ Common Stock, $0.00000625 par value per share │ 7,583,440,247 shares               │
# ╘═══════════════════════════════════════════════╧════════════════════════════════════╛
#
# Table 3 can be found on page:
# ╒══════════════════════════════════════╤══════════╤═══════════════════════════════════════════════════════╤════════════════════════════════╤═══════════════════════════════╕
# │                                      │          │ (In millions, except per share amounts) (Unaudited)   │ Three Months Ended March 31,   │ Nine Months Ended March 31,   │
# ╞══════════════════════════════════════╪══════════╪═══════════════════════════════════════════════════════╪════════════════════════════════╪═══════════════════════════════╡
# │                                      │ 2020     │ 2019                                                  │ 2020                           │ 2019                          │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Revenue:                             │          │                                                       │                                │                               │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Product                              │ $ 15,871 │ $ 15,448                                              │ $ 49,894                       │ $ 48,966                      │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Service and other                    │ 19,150   │ 15,123                                                │ 55,088                         │ 43,160                        │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Total revenue                        │ 35,021   │ 30,571                                                │ 104,982                        │ 92,126                        │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Cost of revenue:                     │          │                                                       │                                │                               │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Product                              │ 3,376    │ 3,441                                                 │ 11,647                         │ 12,975                        │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Service and other                    │ 7,599    │ 6,729                                                 │ 22,092                         │ 19,523                        │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Total cost of revenue                │ 10,975   │ 10,170                                                │ 33,739                         │ 32,498                        │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Gross margin                         │ 24,046   │ 20,401                                                │ 71,243                         │ 59,628                        │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Research and development             │ 4,887    │ 4,316                                                 │ 14,055                         │ 12,363                        │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Sales and marketing                  │ 4,911    │ 4,565                                                 │ 14,181                         │ 13,251                        │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ General and administrative           │ 1,273    │ 1,179                                                 │ 3,455                          │ 3,460                         │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Operating income                     │ 12,975   │ 10,341                                                │ 39,552                         │ 30,554                        │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Other income (expense), net          │ (132)    │ 145                                                   │ 62                             │ 538                           │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Income before income taxes           │ 12,843   │ 10,486                                                │ 39,614                         │ 31,092                        │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Provision for income taxes           │ 2,091    │ 1,677                                                 │ 6,535                          │ 5,039                         │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Net income                           │ $ 10,752 │ $ 8,809                                               │ $ 33,079                       │ $ 26,053                      │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Earnings per share:                  │          │                                                       │                                │                               │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Basic                                │ $ 1.41   │ 1.15                                                  │ $ 4.34                         │ $ 3.39                        │
# │                                      │          │ $                                                     │                                │                               │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Diluted                              │ $ 1.40   │ $ 1.14                                                │ $ 4.30                         │ $ 3.36                        │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Weighted average shares outstanding: │          │                                                       │                                │                               │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Basic                                │ 7,602    │ 7,672                                                 │ 7,619                          │ 7,679                         │
# ├──────────────────────────────────────┼──────────┼───────────────────────────────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Diluted                              │ 7,675    │ 7,744                                                 │ 7,693                          │ 7,759                         │
# ╘══════════════════════════════════════╧══════════╧═══════════════════════════════════════════════════════╧════════════════════════════════╧═══════════════════════════════╛
#
# Table 4 can be found on page:
# ╒════════════════════════════════════════════════╤══════════╤═════════════════════════════╤════════════════════════════════╤═══════════════════════════════╕
# │                                                │          │ (In millions) (Unaudited)   │ Three Months Ended March 31,   │ Nine Months Ended March 31,   │
# ╞════════════════════════════════════════════════╪══════════╪═════════════════════════════╪════════════════════════════════╪═══════════════════════════════╡
# │                                                │ 2020     │ 2019                        │ 2020                           │ 2019                          │
# ├────────────────────────────────────────────────┼──────────┼─────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Net income                                     │ $ 10,752 │ $ 8,809                     │ $ 33,079                       │ $ 26,053                      │
# ├────────────────────────────────────────────────┼──────────┼─────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Other comprehensive income (loss), net of tax: │          │                             │                                │                               │
# ├────────────────────────────────────────────────┼──────────┼─────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Net change related to derivatives              │ (36)     │ (33)                        │ (42)                           │ (93)                          │
# ├────────────────────────────────────────────────┼──────────┼─────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Net change related to investments              │ 3,508    │ 714                         │ 3,665                          │ 1,334                         │
# ├────────────────────────────────────────────────┼──────────┼─────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Translation adjustments and other              │ (541)    │ 67                          │ (607)                          │ (252                          │
# ├────────────────────────────────────────────────┼──────────┼─────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Other comprehensive income                     │ 2,931    │ 748                         │ 3,016                          │ 989                           │
# ├────────────────────────────────────────────────┼──────────┼─────────────────────────────┼────────────────────────────────┼───────────────────────────────┤
# │ Comprehensive income                           │ $ 13,683 │ $ 9,557                     │ $ 36,095                       │ $ 27,042                      │
# ╘════════════════════════════════════════════════╧══════════╧═════════════════════════════╧════════════════════════════════╧═══════════════════════════════╛
#
# Table 5 can be found on page:
# ╒══════════════════════════════════════════════════════════════════════════════════════════╤═══════════╤════════════════════════════════╕
# │                                                                                          │           │ March 31, June 30, 2020 2019   │
# ╞══════════════════════════════════════════════════════════════════════════════════════════╪═══════════╪════════════════════════════════╡
# │ Assets                                                                                   │           │                                │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Current assets:                                                                          │           │                                │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Cash and cash equivalents                                                                │ $ 11,710  │ $ 11,356                       │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Short-term investments                                                                   │ 125,916   │ 122,463                        │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Total cash, cash equivalents, and short-term investments                                 │ 137,626   │ 133,819                        │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Accounts receivable, net of allowance for doubtful accounts of $446 and $411             │ 22,699    │ 29,524                         │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Inventories                                                                              │ 1,644     │ 2,063                          │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Other current assets                                                                     │ 8,536     │ 10,146                         │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Total current assets                                                                     │ 170,505   │ 175,552                        │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Property and equipment, net of accumulated depreciation of $41,512 and $35,330           │ 41,221    │ 36,477                         │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Operating lease right-of-use assets                                                      │ 8,448     │ 7,379                          │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Equity investments                                                                       │ 2,660     │ 2,649                          │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Goodwill                                                                                 │ 42,064    │ 42,026                         │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Intangible assets, net                                                                   │ 6,855     │ 7,750                          │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Other long-term assets                                                                   │ 13,696    │ 14,723                         │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Total assets                                                                             │ $ 285,449 │ $ 286,556                      │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Liabilities and stockholders' equity                                                     │           │                                │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Current liabilities:                                                                     │           │                                │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Accounts payable                                                                         │ $ 9,246   │ $ 9,382                        │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Current portion of long-term debt                                                        │ 3,748     │ 5,516                          │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Accrued compensation                                                                     │ 6,254     │ 6,830                          │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Short-term income taxes                                                                  │ 3,296     │ 5,665                          │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Short-term unearned revenue                                                              │ 27,012    │ 32,676                         │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Other current liabilities                                                                │ 9,151     │ 9,351                          │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Total current liabilities                                                                │ 58,707    │ 69,420                         │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Long-term debt                                                                           │ 62,862    │ 66,662                         │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Long-term income taxes                                                                   │ 28,888    │ 29,612                         │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Long-term unearned revenue                                                               │ 3,385     │ 4,530                          │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Deferred income taxes                                                                    │ 185       │ 233                            │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Operating lease liabilities                                                              │ 7,248     │ 6,188                          │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Other long-term liabilities                                                              │ 9,673     │ 7,581                          │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Total liabilities                                                                        │ 170,948   │ 184,226                        │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Commitments and contingencies                                                            │           │                                │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Stockholders' equity:                                                                    │           │                                │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Common stock and paid-in capital - shares authorized 24,000; outstanding 7,590 and 7,643 │ 79,813    │ 78,520                         │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Retained earnings                                                                        │ 32,012    │ 24,150                         │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Accumulated other comprehensive income (loss)                                            │ 2,676     │ (340)                          │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Total stockholders' equity                                                               │ 114,501   │ 102,330                        │
# ├──────────────────────────────────────────────────────────────────────────────────────────┼───────────┼────────────────────────────────┤
# │ Total liabilities and stockholders' equity                                               │ $ 285,449 │ $ 286,556                      │
# ╘══════════════════════════════════════════════════════════════════════════════════════════╧═══════════╧════════════════════════════════╛
#
# Table 6 can be found on page:
# ╒══════════════════════════════════════════════════════════════════╤══════════╤══════════╤═════════════════════════════╤════════════════════════════════════════════════════════════╕
# │                                                                  │          │          │ (In millions) (Unaudited)   │ Three Months Ended Nine Months Ended March 31, March 31,   │
# ╞══════════════════════════════════════════════════════════════════╪══════════╪══════════╪═════════════════════════════╪════════════════════════════════════════════════════════════╡
# │                                                                  │ 2020     │ 2019     │ 2020                        │ 2019                                                       │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Operations                                                       │          │          │                             │                                                            │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Net income                                                       │ 10,752   │ $ 8,809  │ $ 33,079                    │ $ 26,053                                                   │
# │                                                                  │ $        │          │                             │                                                            │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Adjustments to reconcile net income to net cash from operations: │          │          │                             │                                                            │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Depreciation, amortization, and other                            │ 3,118    │ 2,926    │ 9,292                       │ 8,758                                                      │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Stock-based compensation expense                                 │ 1,338    │ 1,172    │ 3,940                       │ 3,462                                                      │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Net recognized losses (gains) on investments and derivatives     │ 52       │ (95)     │ (140)                       │ (470)                                                      │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Deferred income taxes                                            │ (206)    │ (320)    │ (436)                       │ (740)                                                      │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Changes in operating assets and liabilities:                     │          │          │                             │                                                            │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Accounts receivable                                              │ 891      │ 460      │ 6,778                       │ 7,258                                                      │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Inventories                                                      │ 181      │ 12       │ 419                         │ 710                                                        │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Other current assets                                             │ 94       │ (14)     │ (179)                       │ (864)                                                      │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Other long-term assets                                           │ 124      │ (517)    │ (726)                       │ (969                                                       │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Accounts payable                                                 │ 546      │ (197)    │ (8)                         │ (1,032)                                                    │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Unearned revenue                                                 │ (736)    │ 20       │ (6,564)                     │ (4,543)                                                    │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Income taxes                                                     │ 765      │ 276      │ (3,042)                     │ (879)                                                      │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Other current liabilities                                        │ 695      │ 649      │ (1,136)                     │ (1,017)                                                    │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Other long-term liabilities                                      │ (110)    │ 339      │ 725                         │ 350                                                        │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Net cash from operations                                         │ 17,504   │ 13,520   │ 42,002                      │ 36,077                                                     │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Financing                                                        │          │          │                             │                                                            │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Repayments of debt                                               │ (3,000)  │ 0        │ (5,518)                     │ (3,000)                                                    │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Common stock issued                                              │ 342      │ 274      │ 1,003                       │ 834                                                        │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Common stock repurchased                                         │ (7,059)  │ (4,753)  │ (17,177)                    │ (14,910)                                                   │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Common stock cash dividends paid                                 │ (3,876)  │ (3,526)  │ (11,272)                    │ (10,290)                                                   │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Other, net                                                       │ (1,052)  │ 404      │ (805)                       │ (835)                                                      │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Net cash used in financing                                       │ (14,645) │ (7,601)  │ (33,769)                    │ (28,201)                                                   │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Investing                                                        │          │          │                             │                                                            │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Additions to property and equipment                              │ (3,767)  │ (2,565)  │ (10,697)                    │ (9,874)                                                    │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Acquisition of companies, net of cash acquired, and purchases of │ (329)    │ (269)    │ (871)                       │ (2,107)                                                    │
# │ intangible and other assets                                      │          │          │                             │                                                            │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Purchases of investments                                         │ (15,910) │ (5,846)  │ (58,311)                    │ (42,255)                                                   │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Maturities of investments                                        │ 17,247   │ 5,893    │ 47,559                      │ 14,889                                                     │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Sales of investments                                             │ 2,810    │ 1,424    │ 14,559                      │ 30,831                                                     │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Net cash from (used in) investing                                │ 51       │ (1,363)  │ (7,761)                     │ (8,516)                                                    │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Effect of foreign exchange rates on cash and cash equivalents    │ (64)     │ 18       │ (118)                       │ (94)                                                       │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Net change in cash and cash equivalents                          │ 2,846    │ 4,574    │ 354                         │ (734)                                                      │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Cash and cash equivalents, beginning of period                   │ 8,864    │ 6,638    │ 11,356                      │ 11,946                                                     │
# ├──────────────────────────────────────────────────────────────────┼──────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Cash and cash equivalents, end of period                         │ $ 11,710 │ $ 11,212 │ $ 11,710                    │ $ 11,212                                                   │
# ╘══════════════════════════════════════════════════════════════════╧══════════╧══════════╧═════════════════════════════╧════════════════════════════════════════════════════════════╛
#
# Table 7 can be found on page:
# ╒═══════════════════════════════════════════════╤═══════════╤══════════╤═════════════════════════════╤════════════════════════════════════════════════════════════╕
# │                                               │           │          │ (In millions) (Unaudited)   │ Three Months Ended Nine Months Ended March 31, March 31,   │
# ╞═══════════════════════════════════════════════╪═══════════╪══════════╪═════════════════════════════╪════════════════════════════════════════════════════════════╡
# │                                               │ 2020      │ 2019     │ 2020                        │ 2019                                                       │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Common stock and paid-in capital              │           │          │                             │                                                            │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Balance, beginning of period                  │ $ 79,625  │ $ 77,556 │ $ 78,520                    │ $ 71,223                                                   │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Common stock issued                           │ 342       │ 274      │ 1,003                       │ 6,521                                                      │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Common stock repurchased                      │ (1,492)   │ (1,218)  │ (3,649)                     │ (3,433)                                                    │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Stock-based compensation expense              │ 1,338     │ 1,172    │ 3,940                       │ 3,462                                                      │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Other, net                                    │ 0         │ 7        │ (1)                         │ 18                                                         │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Balance, end of period                        │ 79,813    │ 77,791   │ 79,813                      │ 77,791                                                     │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Retained earnings                             │           │          │                             │                                                            │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Balance, beginning of period                  │ 30,739    │ 16,585   │ 24,150                      │ 13,682                                                     │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Net income                                    │ 10,752    │ 8,809    │ 33,079                      │ 26,053                                                     │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Common stock cash dividends                   │ (3,865)   │ (3,518)  │ (11,627)                    │ (10,592)                                                   │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Common stock repurchased                      │ (5,614)   │ (3,538)  │ (13,590)                    │ (11,482)                                                   │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Cumulative effect of accounting changes       │ 0         │ 0        │ 0                           │ 677                                                        │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Balance, end of period                        │ 32,012    │ 18,338   │ 32,012                      │ 18,338                                                     │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Accumulated other comprehensive income (loss) │           │          │                             │                                                            │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Balance, beginning of period                  │ (255)     │ (2,013)  │ (340)                       │ (2,187)                                                    │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Other comprehensive income                    │ 2,931     │ 748      │ 3,016                       │ 989                                                        │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Cumulative effect of accounting changes       │ 0         │ 0        │ 0                           │ (67)                                                       │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Balance, end of period                        │ 2,676     │ (1,265)  │ 2,676                       │ (1,265)                                                    │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Total stockholders' equity                    │ $ 114,501 │ $ 94,864 │ $ 114,501                   │ $ 94,864                                                   │
# ├───────────────────────────────────────────────┼───────────┼──────────┼─────────────────────────────┼────────────────────────────────────────────────────────────┤
# │ Cash dividends declared per common share      │ $ 0.51    │ $ 0.46   │ $ 1.53                      │ $ 1.38                                                     │
# ╘═══════════════════════════════════════════════╧═══════════╧══════════╧═════════════════════════════╧════════════════════════════════════════════════════════════╛

# %% [markdown]
# ## G. Extracted document insights/ response as a JSON format

# %%
# Import necessary libraries
# json for handling JSON data
# datetime and time for generating timestamps
# AzureJSONEncoder for serializing Python objects to JSON
# urlparse for parsing URLs
import json
import datetime
import time
from azure.core.serialization import AzureJSONEncoder
from urllib.parse import urlparse


# generate the unique file name
filename = datetime.datetime.fromtimestamp(time.time()).strftime('%Y%m%d%H%M%S')+"_"+os.path.splitext(os.path.basename(urlparse(sampleUrl).path))[0]

# parse and format the model response json 
# convert the received model to a dictionary
analyze_result_dict = result.to_dict()

# save the dictionary as JSON content in a JSON file, use the AzureJSONEncoder
# to help make types, such as dates, JSON serializable
with open(str(filename), 'w') as f:
        json.dump(analyze_result_dict, f, cls=AzureJSONEncoder,indent=4)

# convert the dictionary back to the original model
model = AnalyzeResult.from_dict(analyze_result_dict)
print("--------------JSON Response from Model Starts---------------------")
# use the model as normal
print("Model ID: '{}'".format(model.model_id))
print("Number of pages analyzed {}".format(len(model.pages)))
print("API version used: {}".format(model.api_version))
print(json.dumps(analyze_result_dict,cls=AzureJSONEncoder,indent=4))
print("--------------JSON Response from Model Ends---------------------")
# Out:
# --------------JSON Response from Model Starts---------------------
# Model ID: 'customreceiptlrl'
# Number of pages analyzed 10
# API version used: 2023-07-31
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
